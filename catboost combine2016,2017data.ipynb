# %%
import numpy as np
import pandas as pd

import lightgbm as lgb

from sklearn.feature_selection import VarianceThreshold

from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

import time
import datetime as dt
import gc

# %%
train_datapath_2016 = "./zillow data/merged_2016 v4.csv"
train_datapath_2017 = "./zillow data/merged_2017 v4.csv"

test_datapath_2016 = "./zillow data/properties_2016 v4.csv"
test_datapath_2017 = "./zillow data/properties_2017 v4.csv"

# %%
# modify 'transactiondate' of df to keep only the month
def parse_transactiondate(df):
    # modify transactiondate col to keep only the month
    transactiondate_year = []
    transactiondate_month = [] 
    transactiondate_quarter = []
    for data in df['transactiondate']:
        temp = data.split("-")
        year = int(temp[0])
        transactiondate_year.append(year) # keep only month
        month = int(temp[1])
        month = (year - 2016)*12 + month
        transactiondate_month.append(month)
        quarter = (year-2016)*4 + int((month-1)/3) + 1
        transactiondate_quarter.append(quarter)
        
    transactiondate_year = np.array(transactiondate_year)
    transactiondate_year = transactiondate_year.reshape(transactiondate_year.shape[0], 1)
    transactiondate_month = np.array(transactiondate_month)
    transactiondate_month = transactiondate_month.reshape(transactiondate_month.shape[0], 1)
    transactiondate_quarter = np.array(transactiondate_quarter)
    transactiondate_quarter = transactiondate_month.reshape(transactiondate_quarter.shape[0], 1)

    df['transactiondate_year'] = transactiondate_year
    df['transactiondate_month'] = transactiondate_month
    df['transactiondate_quarter'] = transactiondate_quarter
    df = df.drop('transactiondate',axis = 1)
    return df

# return label index, feature index list
# assumes that df label_is_first
def split_on_label(df):
    return df.columns[0], df.columns[1:]

def gen_testdata(df, transactiondate_year,transactiondate_month,transactiondate_quarter):
    df_copy = df.copy()
    # df_copy['transactiondate'] = new_transactiondate
    df_copy.insert(0, 'transactiondate_year', transactiondate_year)
    df_copy.insert(0, 'transactiondate_month', transactiondate_month)
    df_copy.insert(0, 'transactiondate_quarter', transactiondate_quarter)
    return df_copy

def get_low_var_feature(support_list):
    low_var_feature_index = []
    support_feature_index = []
    for i in range(len(support_list)):
        if support_list[i]:
            support_feature_index.append(i)
        else:
            low_var_feature_index.append(i)
    return low_var_feature_index, support_feature_index


def handle_low_var(sel, train_data, feature_list):
    temp_sel = sel.fit(train_data)
    low_var_list, support_list = get_low_var_feature(sel.get_support())

    return low_var_list


# Removing Features with more than 98% missing data
def removing_missing(X_train, missing_threshold = 0.95):
    exclude_missing = []
    num_rows = X_train.shape[0]
    for col in X_train.columns:
        num_missing = X_train[col].isna().sum()
        if num_missing == 0:
            continue
        missing_fraction = num_missing/float(num_rows)
        if missing_fraction > missing_threshold:
            exclude_missing.append(col)
            
    return exclude_missing

# removing features with unique value
def removing_unique(X_train):
    exclude_unique = []
    for col in X_train.columns:
        num_unique = len(X_train[col].unique())
        if X_train[col].isna().sum()!=0 and num_unique == 1:
            exclude_unique.append(col)
            
    return exclude_unique

def print_list(li,list_name = ''):
    print('%s (%d) :' %(list_name,len(li)))
    for i in li:
        print(i)
        
def get_train_features(X_train,el1 = [], el2 = [], el3 = [],el4 = []):
    train_feature = []
    for col in X_train:
        if col not in el1 and col not in el2 and col not in el3 and col not in el4:
            train_feature.append(col)
    return train_feature

# geting categorical features
def get_cat_feature(X_train, cat_threshold):
    cat_feature_inds = []
    cat_feature = []
    for i,col in enumerate(X_train):
        num_uniques = len(X_train[col].unique())
        if num_uniques < cat_threshold and not 'sqft' in col and not 'cnt' in col \
        and not 'nbr' in col and not 'number' in col:
            cat_feature_inds.append(i)
            cat_feature.append(col)
    return cat_feature_inds,cat_feature

# %%
# read training data
train_data16 = pd.read_csv(train_datapath_2016, index_col=0)
train_data17 = pd.read_csv(train_datapath_2017, index_col=0)

# drop parcelid (index of properties features)
train_data16 = train_data16.drop('parcelid', axis=1)
train_data17 = train_data17.drop('parcelid', axis=1)

# modify 'transactiondate' to keep only the month
train_data16 = parse_transactiondate(train_data16)
train_data17 = parse_transactiondate(train_data17)

train_data = pd.concat([train_data16,train_data17],axis = 0)

label, feature = split_on_label(train_data)

# training data and label for model 2016
X_train = train_data[feature]

y_train = train_data[label]

del train_data16, train_data17
gc.collect()

print("[2016] num of features:", len(feature))
print("[2016] num of instances:", train_data.shape[0])
# Out:
# [2016] num of features: 60
# [2016] num of instances: 167888

# %%
# Removing Freatures with too many missing data
exclude_missing = removing_missing(X_train)

# Removing Features with unique values
exclude_unique = removing_unique(X_train)

# Removing Features with low variance
# it should remove features with many missing values that were filled by imputation
#sel = VarianceThreshold(threshold=(.8 * (1 - .8)))

#exclude_low_var16 = handle_low_var(sel, X_train16, feature16)
#exclude_low_var17 = handle_low_var(sel, X_train17, feature17)

# %%
X_train.fillna(-999,inplace=True)
# Out:
# /Users/apple/venv/lib/python3.6/site-packages/pandas/core/frame.py:3790: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
print_list(exclude_missing,'exclude_missing')
#print_list(exclude_low_var16,'exclude_low_var16')
print_list(exclude_unique,'exclude_unique')
# Out:
# exclude_missing (18) :
# architecturalstyletypeid
# basementsqft
# buildingclasstypeid
# decktypeid
# finishedsquarefeet13
# finishedsquarefeet15
# finishedsquarefeet6
# hashottuborspa
# poolsizesum
# pooltypeid10
# pooltypeid2
# storytypeid
# typeconstructiontypeid
# yardbuildingsqft17
# yardbuildingsqft26
# fireplaceflag
# taxdelinquencyflag
# taxdelinquencyyear
# exclude_unique (0) :

# %%
train_feature = get_train_features(X_train, el1 = exclude_missing, 
                                                #el2 = exclude_low_var16,
                                                el3 = exclude_unique)

new_X_train = X_train[train_feature]

print("\n[2016] num of features:", new_X_train.shape[1])
print_list(train_feature,"train_feature16")
# Out:
# [2016] num of features: 42
# train_feature16 (42) :
# airconditioningtypeid
# bathroomcnt
# bedroomcnt
# buildingqualitytypeid
# calculatedbathnbr
# finishedfloor1squarefeet
# calculatedfinishedsquarefeet
# finishedsquarefeet12
# finishedsquarefeet50
# fips
# fireplacecnt
# fullbathcnt
# garagecarcnt
# garagetotalsqft
# heatingorsystemtypeid
# latitude
# longitude
# lotsizesquarefeet
# poolcnt
# pooltypeid7
# propertycountylandusecode
# propertylandusetypeid
# propertyzoningdesc
# rawcensustractandblock
# regionidcity
# regionidcounty
# regionidneighborhood
# regionidzip
# roomcnt
# threequarterbathnbr
# unitcnt
# yearbuilt
# numberofstories
# structuretaxvaluedollarcnt
# taxvaluedollarcnt
# assessmentyear
# landtaxvaluedollarcnt
# taxamount
# censustractandblock
# transactiondate_year
# transactiondate_month
# transactiondate_quarter

# %%
cat_feature_inds, cat_feature = get_cat_feature(new_X_train, cat_threshold = 1000)
print_list(cat_feature,'cat_feature')
# Out:
# cat_feature (16) :
# airconditioningtypeid
# buildingqualitytypeid
# fips
# heatingorsystemtypeid
# pooltypeid7
# propertycountylandusecode
# propertylandusetypeid
# regionidcity
# regionidcounty
# regionidneighborhood
# regionidzip
# yearbuilt
# assessmentyear
# transactiondate_year
# transactiondate_month
# transactiondate_quarter

# %% [markdown]
# ### Feauture Selection

# %%
from catboost import CatBoostRegressor
def handle_catboost_RCV(X, y, param_dict,N):
    
    # cross-validate on alpha (regularization strenght) from alphalist
    
    model = CatBoostRegressor(n_jobs = -1, random_state = 42,silent = False)
       
    # cross-validate on random search CV
    random_search = RandomSearchCV(model,param_distributions=param_dict,
                                 n_iter = N,random_state = 21,
                                 cv=5, scoring='neg_mean_absolute_error',verbose = True)
    
    start = time.time()
    grid_search.fit(X, y)
    print("RandomSearchCV took %.2f seconds"
          " parameter settings." % (time.time() - start))

    return random_search

# %%
def handle_catboost_GridCV(X, y, param_dict,cat_inds):
    
    # cross-validate on alpha (regularization strenght) from alphalist
    
    model = CatBoostRegressor(random_state = 42,silent = False)
       
    # cross-validate on random search CV
    grid_search = GridSearchCV(model,param_grid=param_dict,
                               cv=5, scoring='neg_mean_absolute_error',verbose = True)
    
    start = time.time()
    grid_search.fit(X, y,cat_features = cat_inds)
    print("GridSearchCV took %.2f seconds"
          " parameter settings." % (time.time() - start))

    return grid_search

# %%
params_dict = {
    'learning_rate':[0.03],
    'depth':[6],
    'l2_leaf_reg':[3],
    'iterations':[600]
}
grid_result = handle_catboost_GridCV(new_X_train, y_train, params_dict, cat_feature_inds)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 0:	learn: 0.1642779	total: 468ms	remaining: 4m 40s
# 1:	learn: 0.1642050	total: 823ms	remaining: 4m 6s
# 2:	learn: 0.1641348	total: 1.16s	remaining: 3m 51s
# 3:	learn: 0.1640798	total: 1.59s	remaining: 3m 57s
# 4:	learn: 0.1640169	total: 2s	remaining: 3m 57s
# 5:	learn: 0.1639631	total: 2.38s	remaining: 3m 55s
# 6:	learn: 0.1639082	total: 2.76s	remaining: 3m 53s
# 7:	learn: 0.1638624	total: 3.13s	remaining: 3m 51s
# 8:	learn: 0.1638119	total: 3.52s	remaining: 3m 51s
# 9:	learn: 0.1637796	total: 3.93s	remaining: 3m 51s
# 10:	learn: 0.1637334	total: 4.34s	remaining: 3m 52s
# 11:	learn: 0.1636880	total: 4.73s	remaining: 3m 51s
# 12:	learn: 0.1636470	total: 5.12s	remaining: 3m 51s
# 13:	learn: 0.1636083	total: 5.49s	remaining: 3m 49s
# 14:	learn: 0.1635673	total: 5.86s	remaining: 3m 48s
# 15:	learn: 0.1635314	total: 6.23s	remaining: 3m 47s
# 16:	learn: 0.1634968	total: 6.62s	remaining: 3m 47s
# 17:	learn: 0.1634763	total: 7.11s	remaining: 3m 49s
# 18:	learn: 0.1634472	total: 7.51s	remaining: 3m 49s
# 19:	learn: 0.1634282	total: 7.92s	remaining: 3m 49s
# 20:	learn: 0.1633956	total: 8.26s	remaining: 3m 47s
# 21:	learn: 0.1633797	total: 8.63s	remaining: 3m 46s
# 22:	learn: 0.1633543	total: 9.08s	remaining: 3m 47s
# 23:	learn: 0.1633227	total: 9.43s	remaining: 3m 46s
# 24:	learn: 0.1632995	total: 9.86s	remaining: 3m 46s
# 25:	learn: 0.1632715	total: 10.3s	remaining: 3m 46s
# 26:	learn: 0.1632530	total: 10.7s	remaining: 3m 47s
# 27:	learn: 0.1632344	total: 11.3s	remaining: 3m 49s
# 28:	learn: 0.1632219	total: 11.7s	remaining: 3m 49s
# 29:	learn: 0.1631986	total: 12.2s	remaining: 3m 51s
# 30:	learn: 0.1631703	total: 12.5s	remaining: 3m 50s
# 31:	learn: 0.1631490	total: 13.1s	remaining: 3m 52s
# 32:	learn: 0.1631279	total: 13.5s	remaining: 3m 51s
# 33:	learn: 0.1631171	total: 13.9s	remaining: 3m 50s
# 34:	learn: 0.1631035	total: 14.3s	remaining: 3m 50s
# 35:	learn: 0.1630791	total: 14.7s	remaining: 3m 50s
# 36:	learn: 0.1630641	total: 15.1s	remaining: 3m 50s
# 37:	learn: 0.1630446	total: 15.6s	remaining: 3m 50s
# 38:	learn: 0.1630359	total: 16s	remaining: 3m 50s
# 39:	learn: 0.1630137	total: 16.7s	remaining: 3m 53s
# 40:	learn: 0.1630000	total: 17.3s	remaining: 3m 55s
# 41:	learn: 0.1629880	total: 17.8s	remaining: 3m 55s
# 42:	learn: 0.1629801	total: 18.1s	remaining: 3m 55s
# 43:	learn: 0.1629734	total: 18.6s	remaining: 3m 54s
# 44:	learn: 0.1629538	total: 19s	remaining: 3m 53s
# 45:	learn: 0.1629376	total: 19.4s	remaining: 3m 53s
# 46:	learn: 0.1629239	total: 19.7s	remaining: 3m 51s
# 47:	learn: 0.1629116	total: 20.1s	remaining: 3m 50s
# 48:	learn: 0.1629059	total: 20.5s	remaining: 3m 50s
# 49:	learn: 0.1629004	total: 20.9s	remaining: 3m 49s
# 50:	learn: 0.1628870	total: 21.3s	remaining: 3m 49s
# 51:	learn: 0.1628806	total: 21.8s	remaining: 3m 49s
# 52:	learn: 0.1628786	total: 22.2s	remaining: 3m 49s
# 53:	learn: 0.1628672	total: 22.6s	remaining: 3m 48s
# 54:	learn: 0.1628567	total: 23.2s	remaining: 3m 49s
# 55:	learn: 0.1628519	total: 23.6s	remaining: 3m 49s
# 56:	learn: 0.1628313	total: 23.9s	remaining: 3m 48s
# 57:	learn: 0.1628245	total: 24.4s	remaining: 3m 47s
# 58:	learn: 0.1628218	total: 24.7s	remaining: 3m 46s
# 59:	learn: 0.1628084	total: 25.1s	remaining: 3m 46s
# 60:	learn: 0.1628037	total: 25.5s	remaining: 3m 45s
# 61:	learn: 0.1627931	total: 26s	remaining: 3m 45s
# 62:	learn: 0.1627857	total: 26.4s	remaining: 3m 45s
# 63:	learn: 0.1627842	total: 26.9s	remaining: 3m 45s
# 64:	learn: 0.1627781	total: 27.3s	remaining: 3m 44s
# 65:	learn: 0.1627720	total: 27.8s	remaining: 3m 44s
# 66:	learn: 0.1627691	total: 28.2s	remaining: 3m 44s
# 67:	learn: 0.1627643	total: 28.6s	remaining: 3m 43s
# 68:	learn: 0.1627554	total: 29s	remaining: 3m 43s
# 69:	learn: 0.1627421	total: 29.4s	remaining: 3m 42s
# 70:	learn: 0.1627343	total: 30.3s	remaining: 3m 45s
# 71:	learn: 0.1627258	total: 30.7s	remaining: 3m 45s
# 72:	learn: 0.1627207	total: 31.3s	remaining: 3m 46s
# 73:	learn: 0.1627105	total: 31.7s	remaining: 3m 45s
# 74:	learn: 0.1626926	total: 32.2s	remaining: 3m 45s
# 75:	learn: 0.1626829	total: 32.7s	remaining: 3m 45s
# 76:	learn: 0.1626749	total: 33.1s	remaining: 3m 45s
# 77:	learn: 0.1626699	total: 33.7s	remaining: 3m 45s
# 78:	learn: 0.1626618	total: 34.2s	remaining: 3m 45s
# 79:	learn: 0.1626580	total: 34.8s	remaining: 3m 46s
# 80:	learn: 0.1626446	total: 35.2s	remaining: 3m 45s
# 81:	learn: 0.1626368	total: 35.7s	remaining: 3m 45s
# 82:	learn: 0.1626297	total: 36.2s	remaining: 3m 45s
# 83:	learn: 0.1626204	total: 36.7s	remaining: 3m 45s
# 84:	learn: 0.1626178	total: 37.3s	remaining: 3m 45s
# 85:	learn: 0.1626161	total: 37.8s	remaining: 3m 46s
# 86:	learn: 0.1626084	total: 38.4s	remaining: 3m 46s
# 87:	learn: 0.1626046	total: 38.9s	remaining: 3m 46s
# 88:	learn: 0.1625878	total: 39.3s	remaining: 3m 45s
# 89:	learn: 0.1625855	total: 39.6s	remaining: 3m 44s
# 90:	learn: 0.1625810	total: 40.2s	remaining: 3m 44s
# 91:	learn: 0.1625773	total: 40.6s	remaining: 3m 44s
# 92:	learn: 0.1625700	total: 41s	remaining: 3m 43s
# 93:	learn: 0.1625644	total: 41.4s	remaining: 3m 42s
# 94:	learn: 0.1625587	total: 41.8s	remaining: 3m 42s
# 95:	learn: 0.1625584	total: 42.4s	remaining: 3m 42s
# 96:	learn: 0.1625569	total: 42.8s	remaining: 3m 42s
# 97:	learn: 0.1625535	total: 43.4s	remaining: 3m 42s
# 98:	learn: 0.1625447	total: 43.9s	remaining: 3m 42s
# 99:	learn: 0.1625358	total: 44.5s	remaining: 3m 42s
# 100:	learn: 0.1625266	total: 45s	remaining: 3m 42s
# 101:	learn: 0.1625232	total: 45.7s	remaining: 3m 43s
# 102:	learn: 0.1625147	total: 46.3s	remaining: 3m 43s
# 103:	learn: 0.1625050	total: 47.6s	remaining: 3m 46s
# 104:	learn: 0.1624993	total: 48.1s	remaining: 3m 46s
# 105:	learn: 0.1624950	total: 48.6s	remaining: 3m 46s
# 106:	learn: 0.1624897	total: 49.2s	remaining: 3m 46s
# 107:	learn: 0.1624869	total: 49.8s	remaining: 3m 47s
# 108:	learn: 0.1624844	total: 50.4s	remaining: 3m 47s
# 109:	learn: 0.1624789	total: 50.8s	remaining: 3m 46s
# 110:	learn: 0.1624745	total: 51.4s	remaining: 3m 46s
# 111:	learn: 0.1624682	total: 52s	remaining: 3m 46s
# 112:	learn: 0.1624636	total: 52.8s	remaining: 3m 47s
# 113:	learn: 0.1624614	total: 53.5s	remaining: 3m 48s
# 114:	learn: 0.1624585	total: 54.2s	remaining: 3m 48s
# 115:	learn: 0.1624581	total: 54.6s	remaining: 3m 47s
# 116:	learn: 0.1624517	total: 55.4s	remaining: 3m 48s
# 117:	learn: 0.1624411	total: 56s	remaining: 3m 48s
# 118:	learn: 0.1624366	total: 56.5s	remaining: 3m 48s
# 119:	learn: 0.1624341	total: 57s	remaining: 3m 47s
# 120:	learn: 0.1624285	total: 57.6s	remaining: 3m 47s
# 121:	learn: 0.1624212	total: 57.9s	remaining: 3m 46s
# 122:	learn: 0.1624154	total: 58.6s	remaining: 3m 47s
# 123:	learn: 0.1624099	total: 59s	remaining: 3m 46s
# 124:	learn: 0.1624062	total: 59.5s	remaining: 3m 46s
# 125:	learn: 0.1624049	total: 1m	remaining: 3m 45s
# 126:	learn: 0.1624012	total: 1m	remaining: 3m 45s
# 127:	learn: 0.1623950	total: 1m	remaining: 3m 44s
# 128:	learn: 0.1623843	total: 1m 1s	remaining: 3m 44s
# 129:	learn: 0.1623813	total: 1m 1s	remaining: 3m 43s
# 130:	learn: 0.1623784	total: 1m 2s	remaining: 3m 43s
# 131:	learn: 0.1623744	total: 1m 3s	remaining: 3m 43s
# 132:	learn: 0.1623686	total: 1m 3s	remaining: 3m 43s
# 133:	learn: 0.1623609	total: 1m 3s	remaining: 3m 42s
# 134:	learn: 0.1623581	total: 1m 4s	remaining: 3m 42s
# 135:	learn: 0.1623460	total: 1m 5s	remaining: 3m 42s
# 136:	learn: 0.1623432	total: 1m 5s	remaining: 3m 42s
# 137:	learn: 0.1623423	total: 1m 6s	remaining: 3m 41s
# 138:	learn: 0.1623341	total: 1m 6s	remaining: 3m 41s
# 139:	learn: 0.1623314	total: 1m 7s	remaining: 3m 41s
# 140:	learn: 0.1623250	total: 1m 7s	remaining: 3m 41s
# 141:	learn: 0.1623165	total: 1m 8s	remaining: 3m 40s
# 142:	learn: 0.1623150	total: 1m 8s	remaining: 3m 40s
# 143:	learn: 0.1623133	total: 1m 9s	remaining: 3m 40s
# 144:	learn: 0.1623053	total: 1m 9s	remaining: 3m 39s
# 145:	learn: 0.1622983	total: 1m 10s	remaining: 3m 39s
# 146:	learn: 0.1622889	total: 1m 10s	remaining: 3m 38s
# 147:	learn: 0.1622870	total: 1m 11s	remaining: 3m 38s
# 148:	learn: 0.1622786	total: 1m 11s	remaining: 3m 37s
# 149:	learn: 0.1622741	total: 1m 12s	remaining: 3m 37s
# 150:	learn: 0.1622706	total: 1m 12s	remaining: 3m 36s
# 151:	learn: 0.1622674	total: 1m 13s	remaining: 3m 35s
# 152:	learn: 0.1622640	total: 1m 13s	remaining: 3m 35s
# 153:	learn: 0.1622574	total: 1m 14s	remaining: 3m 34s
# 154:	learn: 0.1622509	total: 1m 14s	remaining: 3m 34s
# 155:	learn: 0.1622485	total: 1m 15s	remaining: 3m 33s
# 156:	learn: 0.1622370	total: 1m 15s	remaining: 3m 33s
# 157:	learn: 0.1622324	total: 1m 16s	remaining: 3m 32s
# 158:	learn: 0.1622306	total: 1m 16s	remaining: 3m 32s
# 159:	learn: 0.1622301	total: 1m 17s	remaining: 3m 31s
# 160:	learn: 0.1622265	total: 1m 17s	remaining: 3m 31s
# 161:	learn: 0.1622215	total: 1m 17s	remaining: 3m 30s
# 162:	learn: 0.1622180	total: 1m 18s	remaining: 3m 29s
# 163:	learn: 0.1622102	total: 1m 18s	remaining: 3m 29s
# 164:	learn: 0.1621985	total: 1m 19s	remaining: 3m 28s
# 165:	learn: 0.1621962	total: 1m 19s	remaining: 3m 28s
# 166:	learn: 0.1621929	total: 1m 20s	remaining: 3m 27s
# 167:	learn: 0.1621846	total: 1m 20s	remaining: 3m 27s
# 168:	learn: 0.1621783	total: 1m 20s	remaining: 3m 26s
# 169:	learn: 0.1621735	total: 1m 21s	remaining: 3m 25s
# 170:	learn: 0.1621706	total: 1m 21s	remaining: 3m 25s
# 171:	learn: 0.1621657	total: 1m 22s	remaining: 3m 25s
# 172:	learn: 0.1621643	total: 1m 22s	remaining: 3m 24s
# 173:	learn: 0.1621586	total: 1m 23s	remaining: 3m 24s
# 174:	learn: 0.1621522	total: 1m 23s	remaining: 3m 23s
# 175:	learn: 0.1621467	total: 1m 24s	remaining: 3m 23s
# 176:	learn: 0.1621400	total: 1m 24s	remaining: 3m 22s
# 177:	learn: 0.1621380	total: 1m 25s	remaining: 3m 22s
# 178:	learn: 0.1621350	total: 1m 25s	remaining: 3m 21s
# 179:	learn: 0.1621321	total: 1m 26s	remaining: 3m 21s
# 180:	learn: 0.1621285	total: 1m 26s	remaining: 3m 20s
# 181:	learn: 0.1621273	total: 1m 26s	remaining: 3m 19s
# 182:	learn: 0.1621227	total: 1m 27s	remaining: 3m 19s
# 183:	learn: 0.1621213	total: 1m 27s	remaining: 3m 18s
# 184:	learn: 0.1621098	total: 1m 28s	remaining: 3m 17s
# 185:	learn: 0.1621068	total: 1m 28s	remaining: 3m 17s
# 186:	learn: 0.1621035	total: 1m 29s	remaining: 3m 16s
# 187:	learn: 0.1620943	total: 1m 29s	remaining: 3m 15s
# 188:	learn: 0.1620873	total: 1m 29s	remaining: 3m 15s
# 189:	learn: 0.1620839	total: 1m 30s	remaining: 3m 14s
# 190:	learn: 0.1620703	total: 1m 30s	remaining: 3m 13s
# 191:	learn: 0.1620663	total: 1m 30s	remaining: 3m 13s
# 192:	learn: 0.1620614	total: 1m 31s	remaining: 3m 12s
# 193:	learn: 0.1620589	total: 1m 31s	remaining: 3m 11s
# 194:	learn: 0.1620548	total: 1m 32s	remaining: 3m 11s
# 195:	learn: 0.1620539	total: 1m 32s	remaining: 3m 10s
# 196:	learn: 0.1620500	total: 1m 32s	remaining: 3m 10s
# 197:	learn: 0.1620466	total: 1m 33s	remaining: 3m 9s
# 198:	learn: 0.1620435	total: 1m 33s	remaining: 3m 9s
# 199:	learn: 0.1620397	total: 1m 34s	remaining: 3m 8s
# 200:	learn: 0.1620385	total: 1m 34s	remaining: 3m 7s
# 201:	learn: 0.1620365	total: 1m 35s	remaining: 3m 7s
# 202:	learn: 0.1620343	total: 1m 35s	remaining: 3m 6s
# 203:	learn: 0.1620320	total: 1m 36s	remaining: 3m 6s
# 204:	learn: 0.1620319	total: 1m 36s	remaining: 3m 5s
# 205:	learn: 0.1620309	total: 1m 36s	remaining: 3m 5s
# 206:	learn: 0.1620262	total: 1m 37s	remaining: 3m 4s
# 207:	learn: 0.1620223	total: 1m 37s	remaining: 3m 4s
# 208:	learn: 0.1620195	total: 1m 38s	remaining: 3m 3s
# 209:	learn: 0.1620151	total: 1m 38s	remaining: 3m 2s
# 210:	learn: 0.1620120	total: 1m 38s	remaining: 3m 2s
# 211:	learn: 0.1620110	total: 1m 39s	remaining: 3m 1s
# 212:	learn: 0.1620096	total: 1m 39s	remaining: 3m 1s
# 213:	learn: 0.1620086	total: 1m 40s	remaining: 3m
# 214:	learn: 0.1619967	total: 1m 40s	remaining: 2m 59s
# 215:	learn: 0.1619954	total: 1m 40s	remaining: 2m 59s
# 216:	learn: 0.1619925	total: 1m 41s	remaining: 2m 58s
# 217:	learn: 0.1619849	total: 1m 41s	remaining: 2m 58s
# 218:	learn: 0.1619809	total: 1m 42s	remaining: 2m 57s
# 219:	learn: 0.1619782	total: 1m 42s	remaining: 2m 57s
# 220:	learn: 0.1619740	total: 1m 42s	remaining: 2m 56s
# 221:	learn: 0.1619722	total: 1m 43s	remaining: 2m 56s
# 222:	learn: 0.1619718	total: 1m 43s	remaining: 2m 55s
# 223:	learn: 0.1619687	total: 1m 44s	remaining: 2m 54s
# 224:	learn: 0.1619661	total: 1m 44s	remaining: 2m 54s
# 225:	learn: 0.1619647	total: 1m 44s	remaining: 2m 53s
# 226:	learn: 0.1619635	total: 1m 45s	remaining: 2m 53s
# 227:	learn: 0.1619604	total: 1m 45s	remaining: 2m 52s
# 228:	learn: 0.1619535	total: 1m 46s	remaining: 2m 51s
# 229:	learn: 0.1619518	total: 1m 46s	remaining: 2m 51s
# 230:	learn: 0.1619515	total: 1m 46s	remaining: 2m 50s
# 231:	learn: 0.1619510	total: 1m 47s	remaining: 2m 50s
# 232:	learn: 0.1619492	total: 1m 47s	remaining: 2m 49s
# 233:	learn: 0.1619480	total: 1m 48s	remaining: 2m 49s
# 234:	learn: 0.1619448	total: 1m 48s	remaining: 2m 48s
# 235:	learn: 0.1619416	total: 1m 49s	remaining: 2m 48s
# 236:	learn: 0.1619341	total: 1m 49s	remaining: 2m 47s
# 237:	learn: 0.1619302	total: 1m 49s	remaining: 2m 46s
# 238:	learn: 0.1619249	total: 1m 50s	remaining: 2m 46s
# 239:	learn: 0.1619231	total: 1m 50s	remaining: 2m 46s
# 240:	learn: 0.1619180	total: 1m 51s	remaining: 2m 45s
# 241:	learn: 0.1619164	total: 1m 51s	remaining: 2m 45s
# 242:	learn: 0.1619141	total: 1m 52s	remaining: 2m 45s
# 243:	learn: 0.1619129	total: 1m 53s	remaining: 2m 44s
# 244:	learn: 0.1619110	total: 1m 53s	remaining: 2m 44s
# 245:	learn: 0.1619103	total: 1m 54s	remaining: 2m 44s
# 246:	learn: 0.1619065	total: 1m 54s	remaining: 2m 44s
# 247:	learn: 0.1619038	total: 1m 55s	remaining: 2m 43s
# 248:	learn: 0.1618993	total: 1m 55s	remaining: 2m 43s
# 249:	learn: 0.1618937	total: 1m 56s	remaining: 2m 42s
# 250:	learn: 0.1618886	total: 1m 56s	remaining: 2m 42s
# 251:	learn: 0.1618799	total: 1m 57s	remaining: 2m 41s
# 252:	learn: 0.1618754	total: 1m 57s	remaining: 2m 41s
# 253:	learn: 0.1618752	total: 1m 58s	remaining: 2m 40s
# 254:	learn: 0.1618743	total: 1m 58s	remaining: 2m 40s
# 255:	learn: 0.1618740	total: 1m 59s	remaining: 2m 40s
# 256:	learn: 0.1618710	total: 1m 59s	remaining: 2m 39s
# 257:	learn: 0.1618702	total: 1m 59s	remaining: 2m 39s
# 258:	learn: 0.1618686	total: 2m	remaining: 2m 38s
# 259:	learn: 0.1618657	total: 2m	remaining: 2m 38s
# 260:	learn: 0.1618576	total: 2m 1s	remaining: 2m 37s
# 261:	learn: 0.1618497	total: 2m 1s	remaining: 2m 37s
# 262:	learn: 0.1618480	total: 2m 2s	remaining: 2m 36s
# 263:	learn: 0.1618452	total: 2m 3s	remaining: 2m 36s
# 264:	learn: 0.1618387	total: 2m 3s	remaining: 2m 36s
# 265:	learn: 0.1618365	total: 2m 4s	remaining: 2m 36s
# 266:	learn: 0.1618329	total: 2m 4s	remaining: 2m 35s
# 267:	learn: 0.1618322	total: 2m 5s	remaining: 2m 35s
# 268:	learn: 0.1618301	total: 2m 5s	remaining: 2m 34s
# 269:	learn: 0.1618294	total: 2m 6s	remaining: 2m 34s
# 270:	learn: 0.1618292	total: 2m 6s	remaining: 2m 33s
# 271:	learn: 0.1618276	total: 2m 7s	remaining: 2m 33s
# 272:	learn: 0.1618180	total: 2m 7s	remaining: 2m 33s
# 273:	learn: 0.1618146	total: 2m 8s	remaining: 2m 32s
# 274:	learn: 0.1618126	total: 2m 8s	remaining: 2m 32s
# 275:	learn: 0.1618092	total: 2m 9s	remaining: 2m 31s
# 276:	learn: 0.1618070	total: 2m 9s	remaining: 2m 31s
# 277:	learn: 0.1618060	total: 2m 10s	remaining: 2m 30s
# 278:	learn: 0.1618056	total: 2m 10s	remaining: 2m 30s
# 279:	learn: 0.1618002	total: 2m 11s	remaining: 2m 29s
# 280:	learn: 0.1617973	total: 2m 11s	remaining: 2m 29s
# 281:	learn: 0.1617962	total: 2m 12s	remaining: 2m 28s
# 282:	learn: 0.1617934	total: 2m 12s	remaining: 2m 28s
# 283:	learn: 0.1617913	total: 2m 12s	remaining: 2m 27s
# 284:	learn: 0.1617870	total: 2m 13s	remaining: 2m 27s
# 285:	learn: 0.1617848	total: 2m 13s	remaining: 2m 26s
# 286:	learn: 0.1617820	total: 2m 14s	remaining: 2m 26s
# 287:	learn: 0.1617692	total: 2m 14s	remaining: 2m 25s
# 288:	learn: 0.1617652	total: 2m 15s	remaining: 2m 25s
# 289:	learn: 0.1617650	total: 2m 15s	remaining: 2m 25s
# 290:	learn: 0.1617621	total: 2m 16s	remaining: 2m 24s
# 291:	learn: 0.1617591	total: 2m 16s	remaining: 2m 24s
# 292:	learn: 0.1617533	total: 2m 17s	remaining: 2m 23s
# 293:	learn: 0.1617494	total: 2m 17s	remaining: 2m 23s
# 294:	learn: 0.1617438	total: 2m 18s	remaining: 2m 22s
# 295:	learn: 0.1617423	total: 2m 18s	remaining: 2m 22s
# 296:	learn: 0.1617412	total: 2m 19s	remaining: 2m 21s
# 297:	learn: 0.1617371	total: 2m 19s	remaining: 2m 21s
# 298:	learn: 0.1617359	total: 2m 19s	remaining: 2m 20s
# 299:	learn: 0.1617336	total: 2m 20s	remaining: 2m 20s
# 300:	learn: 0.1617328	total: 2m 20s	remaining: 2m 20s
# 301:	learn: 0.1617327	total: 2m 21s	remaining: 2m 19s
# 302:	learn: 0.1617314	total: 2m 21s	remaining: 2m 19s
# 303:	learn: 0.1617286	total: 2m 22s	remaining: 2m 18s
# 304:	learn: 0.1617229	total: 2m 22s	remaining: 2m 18s
# 305:	learn: 0.1617128	total: 2m 23s	remaining: 2m 17s
# 306:	learn: 0.1617119	total: 2m 23s	remaining: 2m 17s
# 307:	learn: 0.1617080	total: 2m 24s	remaining: 2m 16s
# 308:	learn: 0.1617068	total: 2m 24s	remaining: 2m 16s
# 309:	learn: 0.1617049	total: 2m 25s	remaining: 2m 16s
# 310:	learn: 0.1617049	total: 2m 26s	remaining: 2m 15s
# 311:	learn: 0.1617038	total: 2m 26s	remaining: 2m 15s
# 312:	learn: 0.1616979	total: 2m 27s	remaining: 2m 15s
# 313:	learn: 0.1616969	total: 2m 28s	remaining: 2m 15s
# 314:	learn: 0.1616945	total: 2m 28s	remaining: 2m 14s
# 315:	learn: 0.1616924	total: 2m 29s	remaining: 2m 14s
# 316:	learn: 0.1616918	total: 2m 29s	remaining: 2m 13s
# 317:	learn: 0.1616912	total: 2m 30s	remaining: 2m 13s
# 318:	learn: 0.1616887	total: 2m 30s	remaining: 2m 12s
# 319:	learn: 0.1616867	total: 2m 31s	remaining: 2m 12s
# 320:	learn: 0.1616826	total: 2m 31s	remaining: 2m 11s
# 321:	learn: 0.1616769	total: 2m 32s	remaining: 2m 11s
# 322:	learn: 0.1616749	total: 2m 33s	remaining: 2m 11s
# 323:	learn: 0.1616688	total: 2m 33s	remaining: 2m 10s
# 324:	learn: 0.1616675	total: 2m 34s	remaining: 2m 10s
# 325:	learn: 0.1616657	total: 2m 34s	remaining: 2m 10s
# 326:	learn: 0.1616656	total: 2m 35s	remaining: 2m 9s
# 327:	learn: 0.1616602	total: 2m 36s	remaining: 2m 9s
# 328:	learn: 0.1616600	total: 2m 36s	remaining: 2m 9s
# 329:	learn: 0.1616454	total: 2m 37s	remaining: 2m 8s
# 330:	learn: 0.1616409	total: 2m 38s	remaining: 2m 8s
# 331:	learn: 0.1616374	total: 2m 38s	remaining: 2m 7s
# 332:	learn: 0.1616366	total: 2m 39s	remaining: 2m 7s
# 333:	learn: 0.1616336	total: 2m 39s	remaining: 2m 7s
# 334:	learn: 0.1616314	total: 2m 40s	remaining: 2m 6s
# 335:	learn: 0.1616259	total: 2m 40s	remaining: 2m 6s
# 336:	learn: 0.1616251	total: 2m 41s	remaining: 2m 5s
# 337:	learn: 0.1616217	total: 2m 41s	remaining: 2m 5s
# 338:	learn: 0.1616183	total: 2m 42s	remaining: 2m 5s
# 339:	learn: 0.1616146	total: 2m 42s	remaining: 2m 4s
# 340:	learn: 0.1616139	total: 2m 43s	remaining: 2m 4s
# 341:	learn: 0.1616051	total: 2m 43s	remaining: 2m 3s
# 342:	learn: 0.1616048	total: 2m 44s	remaining: 2m 3s
# 343:	learn: 0.1616038	total: 2m 44s	remaining: 2m 2s
# 344:	learn: 0.1616009	total: 2m 45s	remaining: 2m 2s
# 345:	learn: 0.1615986	total: 2m 45s	remaining: 2m 1s
# 346:	learn: 0.1615977	total: 2m 46s	remaining: 2m 1s
# 347:	learn: 0.1615947	total: 2m 46s	remaining: 2m
# 348:	learn: 0.1615928	total: 2m 46s	remaining: 1m 59s
# 349:	learn: 0.1615922	total: 2m 47s	remaining: 1m 59s
# 350:	learn: 0.1615915	total: 2m 47s	remaining: 1m 58s
# 351:	learn: 0.1615908	total: 2m 48s	remaining: 1m 58s
# 352:	learn: 0.1615836	total: 2m 48s	remaining: 1m 57s
# 353:	learn: 0.1615805	total: 2m 48s	remaining: 1m 57s
# 354:	learn: 0.1615709	total: 2m 49s	remaining: 1m 56s
# 355:	learn: 0.1615656	total: 2m 49s	remaining: 1m 56s
# 356:	learn: 0.1615627	total: 2m 50s	remaining: 1m 55s
# 357:	learn: 0.1615603	total: 2m 50s	remaining: 1m 55s
# 358:	learn: 0.1615600	total: 2m 51s	remaining: 1m 54s
# 359:	learn: 0.1615519	total: 2m 51s	remaining: 1m 54s
# 360:	learn: 0.1615495	total: 2m 52s	remaining: 1m 53s
# 361:	learn: 0.1615493	total: 2m 52s	remaining: 1m 53s
# 362:	learn: 0.1615477	total: 2m 52s	remaining: 1m 52s
# 363:	learn: 0.1615449	total: 2m 53s	remaining: 1m 52s
# 364:	learn: 0.1615375	total: 2m 53s	remaining: 1m 51s
# 365:	learn: 0.1615367	total: 2m 54s	remaining: 1m 51s
# 366:	learn: 0.1615290	total: 2m 54s	remaining: 1m 50s
# 367:	learn: 0.1615262	total: 2m 54s	remaining: 1m 50s
# 368:	learn: 0.1615259	total: 2m 55s	remaining: 1m 49s
# 369:	learn: 0.1615208	total: 2m 55s	remaining: 1m 49s
# 370:	learn: 0.1615190	total: 2m 56s	remaining: 1m 48s
# 371:	learn: 0.1615164	total: 2m 56s	remaining: 1m 48s
# 372:	learn: 0.1615146	total: 2m 57s	remaining: 1m 47s
# 373:	learn: 0.1615107	total: 2m 57s	remaining: 1m 47s
# 374:	learn: 0.1615078	total: 2m 57s	remaining: 1m 46s
# 375:	learn: 0.1615040	total: 2m 58s	remaining: 1m 46s
# 376:	learn: 0.1615034	total: 2m 58s	remaining: 1m 45s
# 377:	learn: 0.1615016	total: 2m 59s	remaining: 1m 45s
# 378:	learn: 0.1614968	total: 2m 59s	remaining: 1m 44s
# 379:	learn: 0.1614899	total: 3m	remaining: 1m 44s
# 380:	learn: 0.1614877	total: 3m	remaining: 1m 43s
# 381:	learn: 0.1614846	total: 3m	remaining: 1m 43s
# 382:	learn: 0.1614808	total: 3m 1s	remaining: 1m 42s
# 383:	learn: 0.1614801	total: 3m 1s	remaining: 1m 42s
# 384:	learn: 0.1614786	total: 3m 2s	remaining: 1m 41s
# 385:	learn: 0.1614755	total: 3m 2s	remaining: 1m 41s
# 386:	learn: 0.1614744	total: 3m 3s	remaining: 1m 40s
# 387:	learn: 0.1614709	total: 3m 3s	remaining: 1m 40s
# 388:	learn: 0.1614701	total: 3m 3s	remaining: 1m 39s
# 389:	learn: 0.1614694	total: 3m 4s	remaining: 1m 39s
# 390:	learn: 0.1614662	total: 3m 4s	remaining: 1m 38s
# 391:	learn: 0.1614633	total: 3m 5s	remaining: 1m 38s
# 392:	learn: 0.1614574	total: 3m 5s	remaining: 1m 37s
# 393:	learn: 0.1614541	total: 3m 5s	remaining: 1m 37s
# 394:	learn: 0.1614531	total: 3m 6s	remaining: 1m 36s
# 395:	learn: 0.1614529	total: 3m 6s	remaining: 1m 36s
# 396:	learn: 0.1614522	total: 3m 7s	remaining: 1m 35s
# 397:	learn: 0.1614429	total: 3m 7s	remaining: 1m 35s
# 398:	learn: 0.1614392	total: 3m 8s	remaining: 1m 34s
# 399:	learn: 0.1614384	total: 3m 8s	remaining: 1m 34s
# 400:	learn: 0.1614351	total: 3m 8s	remaining: 1m 33s
# 401:	learn: 0.1614329	total: 3m 9s	remaining: 1m 33s
# 402:	learn: 0.1614314	total: 3m 9s	remaining: 1m 32s
# 403:	learn: 0.1614303	total: 3m 10s	remaining: 1m 32s
# 404:	learn: 0.1614293	total: 3m 10s	remaining: 1m 31s
# 405:	learn: 0.1614279	total: 3m 11s	remaining: 1m 31s
# 406:	learn: 0.1614222	total: 3m 11s	remaining: 1m 30s
# 407:	learn: 0.1614199	total: 3m 11s	remaining: 1m 30s
# 408:	learn: 0.1614129	total: 3m 12s	remaining: 1m 29s
# 409:	learn: 0.1614058	total: 3m 12s	remaining: 1m 29s
# 410:	learn: 0.1614040	total: 3m 13s	remaining: 1m 28s
# 411:	learn: 0.1614022	total: 3m 13s	remaining: 1m 28s
# 412:	learn: 0.1613995	total: 3m 14s	remaining: 1m 27s
# 413:	learn: 0.1613979	total: 3m 14s	remaining: 1m 27s
# 414:	learn: 0.1613958	total: 3m 14s	remaining: 1m 26s
# 415:	learn: 0.1613882	total: 3m 15s	remaining: 1m 26s
# 416:	learn: 0.1613879	total: 3m 15s	remaining: 1m 25s
# 417:	learn: 0.1613868	total: 3m 16s	remaining: 1m 25s
# 418:	learn: 0.1613862	total: 3m 16s	remaining: 1m 24s
# 419:	learn: 0.1613852	total: 3m 17s	remaining: 1m 24s
# 420:	learn: 0.1613831	total: 3m 17s	remaining: 1m 23s
# 421:	learn: 0.1613826	total: 3m 17s	remaining: 1m 23s
# 422:	learn: 0.1613804	total: 3m 18s	remaining: 1m 23s
# 423:	learn: 0.1613797	total: 3m 19s	remaining: 1m 22s
# 424:	learn: 0.1613736	total: 3m 19s	remaining: 1m 22s
# 425:	learn: 0.1613722	total: 3m 20s	remaining: 1m 21s
# 426:	learn: 0.1613699	total: 3m 20s	remaining: 1m 21s
# 427:	learn: 0.1613676	total: 3m 21s	remaining: 1m 21s
# 428:	learn: 0.1613662	total: 3m 22s	remaining: 1m 20s
# 429:	learn: 0.1613654	total: 3m 22s	remaining: 1m 20s
# 430:	learn: 0.1613642	total: 3m 23s	remaining: 1m 19s
# 431:	learn: 0.1613527	total: 3m 23s	remaining: 1m 19s
# 432:	learn: 0.1613502	total: 3m 24s	remaining: 1m 18s
# 433:	learn: 0.1613471	total: 3m 24s	remaining: 1m 18s
# 434:	learn: 0.1613458	total: 3m 25s	remaining: 1m 17s
# 435:	learn: 0.1613457	total: 3m 25s	remaining: 1m 17s
# 436:	learn: 0.1613428	total: 3m 26s	remaining: 1m 16s
# 437:	learn: 0.1613413	total: 3m 26s	remaining: 1m 16s
# 438:	learn: 0.1613355	total: 3m 27s	remaining: 1m 15s
# 439:	learn: 0.1613341	total: 3m 27s	remaining: 1m 15s
# 440:	learn: 0.1613253	total: 3m 28s	remaining: 1m 15s
# 441:	learn: 0.1613202	total: 3m 28s	remaining: 1m 14s
# 442:	learn: 0.1613123	total: 3m 28s	remaining: 1m 14s
# 443:	learn: 0.1613052	total: 3m 29s	remaining: 1m 13s
# 444:	learn: 0.1612977	total: 3m 29s	remaining: 1m 13s
# 445:	learn: 0.1612975	total: 3m 30s	remaining: 1m 12s
# 446:	learn: 0.1612969	total: 3m 30s	remaining: 1m 12s
# 447:	learn: 0.1612892	total: 3m 31s	remaining: 1m 11s
# 448:	learn: 0.1612875	total: 3m 31s	remaining: 1m 11s
# 449:	learn: 0.1612852	total: 3m 32s	remaining: 1m 10s
# 450:	learn: 0.1612819	total: 3m 32s	remaining: 1m 10s
# 451:	learn: 0.1612810	total: 3m 33s	remaining: 1m 9s
# 452:	learn: 0.1612802	total: 3m 33s	remaining: 1m 9s
# 453:	learn: 0.1612802	total: 3m 33s	remaining: 1m 8s
# 454:	learn: 0.1612796	total: 3m 34s	remaining: 1m 8s
# 455:	learn: 0.1612775	total: 3m 34s	remaining: 1m 7s
# 456:	learn: 0.1612735	total: 3m 35s	remaining: 1m 7s
# 457:	learn: 0.1612726	total: 3m 35s	remaining: 1m 6s
# 458:	learn: 0.1612717	total: 3m 36s	remaining: 1m 6s
# 459:	learn: 0.1612695	total: 3m 36s	remaining: 1m 5s
# 460:	learn: 0.1612627	total: 3m 37s	remaining: 1m 5s
# 461:	learn: 0.1612615	total: 3m 37s	remaining: 1m 5s
# 462:	learn: 0.1612603	total: 3m 38s	remaining: 1m 4s
# 463:	learn: 0.1612503	total: 3m 38s	remaining: 1m 4s
# 464:	learn: 0.1612434	total: 3m 38s	remaining: 1m 3s
# 465:	learn: 0.1612400	total: 3m 39s	remaining: 1m 3s
# 466:	learn: 0.1612352	total: 3m 39s	remaining: 1m 2s
# 467:	learn: 0.1612338	total: 3m 40s	remaining: 1m 2s
# 468:	learn: 0.1612333	total: 3m 40s	remaining: 1m 1s
# 469:	learn: 0.1612316	total: 3m 41s	remaining: 1m 1s
# 470:	learn: 0.1612291	total: 3m 41s	remaining: 1m
# 471:	learn: 0.1612284	total: 3m 42s	remaining: 1m
# 472:	learn: 0.1612251	total: 3m 42s	remaining: 59.8s
# 473:	learn: 0.1612244	total: 3m 43s	remaining: 59.3s
# 474:	learn: 0.1612243	total: 3m 43s	remaining: 58.8s
# 475:	learn: 0.1612193	total: 3m 44s	remaining: 58.4s
# 476:	learn: 0.1612180	total: 3m 44s	remaining: 57.9s
# 477:	learn: 0.1612149	total: 3m 44s	remaining: 57.4s
# 478:	learn: 0.1612131	total: 3m 45s	remaining: 57s
# 479:	learn: 0.1612125	total: 3m 46s	remaining: 56.5s
# 480:	learn: 0.1612097	total: 3m 46s	remaining: 56s
# 481:	learn: 0.1612096	total: 3m 47s	remaining: 55.6s
# 482:	learn: 0.1612001	total: 3m 47s	remaining: 55.1s
# 483:	learn: 0.1611992	total: 3m 48s	remaining: 54.6s
# 484:	learn: 0.1611983	total: 3m 48s	remaining: 54.2s
# 485:	learn: 0.1611933	total: 3m 49s	remaining: 53.7s
# 486:	learn: 0.1611865	total: 3m 49s	remaining: 53.2s
# 487:	learn: 0.1611852	total: 3m 49s	remaining: 52.8s
# 488:	learn: 0.1611830	total: 3m 50s	remaining: 52.3s
# 489:	learn: 0.1611821	total: 3m 50s	remaining: 51.8s
# 490:	learn: 0.1611815	total: 3m 51s	remaining: 51.4s
# 491:	learn: 0.1611746	total: 3m 51s	remaining: 50.9s
# 492:	learn: 0.1611711	total: 3m 52s	remaining: 50.4s
# 493:	learn: 0.1611696	total: 3m 52s	remaining: 50s
# 494:	learn: 0.1611660	total: 3m 53s	remaining: 49.5s
# 495:	learn: 0.1611658	total: 3m 53s	remaining: 49s
# 496:	learn: 0.1611646	total: 3m 54s	remaining: 48.6s
# 497:	learn: 0.1611642	total: 3m 54s	remaining: 48.1s
# 498:	learn: 0.1611633	total: 3m 55s	remaining: 47.6s
# 499:	learn: 0.1611625	total: 3m 55s	remaining: 47.2s
# 500:	learn: 0.1611606	total: 3m 56s	remaining: 46.7s
# 501:	learn: 0.1611598	total: 3m 56s	remaining: 46.2s
# 502:	learn: 0.1611579	total: 3m 57s	remaining: 45.8s
# 503:	learn: 0.1611550	total: 3m 57s	remaining: 45.3s
# 504:	learn: 0.1611528	total: 3m 58s	remaining: 44.8s
# 505:	learn: 0.1611515	total: 3m 58s	remaining: 44.4s
# 506:	learn: 0.1611499	total: 3m 59s	remaining: 43.9s
# 507:	learn: 0.1611461	total: 3m 59s	remaining: 43.4s
# 508:	learn: 0.1611430	total: 4m	remaining: 43s
# 509:	learn: 0.1611422	total: 4m	remaining: 42.5s
# 510:	learn: 0.1611352	total: 4m 1s	remaining: 42s
# 511:	learn: 0.1611338	total: 4m 1s	remaining: 41.5s
# 512:	learn: 0.1611267	total: 4m 2s	remaining: 41.1s
# 513:	learn: 0.1611245	total: 4m 2s	remaining: 40.6s
# 514:	learn: 0.1611213	total: 4m 3s	remaining: 40.1s
# 515:	learn: 0.1611190	total: 4m 3s	remaining: 39.7s
# 516:	learn: 0.1611163	total: 4m 4s	remaining: 39.2s
# 517:	learn: 0.1611150	total: 4m 4s	remaining: 38.8s
# 518:	learn: 0.1611125	total: 4m 5s	remaining: 38.3s
# 519:	learn: 0.1611101	total: 4m 5s	remaining: 37.8s
# 520:	learn: 0.1611055	total: 4m 6s	remaining: 37.4s
# 521:	learn: 0.1611037	total: 4m 6s	remaining: 36.9s
# 522:	learn: 0.1610972	total: 4m 7s	remaining: 36.4s
# 523:	learn: 0.1610970	total: 4m 7s	remaining: 35.9s
# 524:	learn: 0.1610962	total: 4m 8s	remaining: 35.5s
# 525:	learn: 0.1610957	total: 4m 8s	remaining: 35s
# 526:	learn: 0.1610915	total: 4m 9s	remaining: 34.5s
# 527:	learn: 0.1610915	total: 4m 9s	remaining: 34s
# 528:	learn: 0.1610882	total: 4m 9s	remaining: 33.5s
# 529:	learn: 0.1610825	total: 4m 10s	remaining: 33.1s
# 530:	learn: 0.1610791	total: 4m 10s	remaining: 32.6s
# 531:	learn: 0.1610790	total: 4m 11s	remaining: 32.1s
# 532:	learn: 0.1610734	total: 4m 11s	remaining: 31.6s
# 533:	learn: 0.1610716	total: 4m 12s	remaining: 31.2s
# 534:	learn: 0.1610713	total: 4m 12s	remaining: 30.7s
# 535:	learn: 0.1610703	total: 4m 13s	remaining: 30.2s
# 536:	learn: 0.1610664	total: 4m 13s	remaining: 29.7s
# 537:	learn: 0.1610613	total: 4m 13s	remaining: 29.2s
# 538:	learn: 0.1610609	total: 4m 14s	remaining: 28.8s
# 539:	learn: 0.1610592	total: 4m 14s	remaining: 28.3s
# 540:	learn: 0.1610575	total: 4m 15s	remaining: 27.8s
# 541:	learn: 0.1610525	total: 4m 15s	remaining: 27.3s
# 542:	learn: 0.1610475	total: 4m 15s	remaining: 26.9s
# 543:	learn: 0.1610463	total: 4m 16s	remaining: 26.4s
# 544:	learn: 0.1610446	total: 4m 16s	remaining: 25.9s
# 545:	learn: 0.1610439	total: 4m 17s	remaining: 25.4s
# 546:	learn: 0.1610433	total: 4m 17s	remaining: 25s
# 547:	learn: 0.1610329	total: 4m 17s	remaining: 24.5s
# 548:	learn: 0.1610316	total: 4m 18s	remaining: 24s
# 549:	learn: 0.1610310	total: 4m 18s	remaining: 23.5s
# 550:	learn: 0.1610304	total: 4m 19s	remaining: 23.1s
# 551:	learn: 0.1610278	total: 4m 19s	remaining: 22.6s
# 552:	learn: 0.1610260	total: 4m 20s	remaining: 22.1s
# 553:	learn: 0.1610241	total: 4m 20s	remaining: 21.6s
# 554:	learn: 0.1610230	total: 4m 20s	remaining: 21.2s
# 555:	learn: 0.1610187	total: 4m 21s	remaining: 20.7s
# 556:	learn: 0.1610167	total: 4m 21s	remaining: 20.2s
# 557:	learn: 0.1610129	total: 4m 22s	remaining: 19.7s
# 558:	learn: 0.1610113	total: 4m 22s	remaining: 19.3s
# 559:	learn: 0.1610099	total: 4m 23s	remaining: 18.8s
# 560:	learn: 0.1610084	total: 4m 23s	remaining: 18.3s
# 561:	learn: 0.1610075	total: 4m 23s	remaining: 17.8s
# 562:	learn: 0.1610049	total: 4m 24s	remaining: 17.4s
# 563:	learn: 0.1610045	total: 4m 24s	remaining: 16.9s
# 564:	learn: 0.1610004	total: 4m 24s	remaining: 16.4s
# 565:	learn: 0.1609983	total: 4m 25s	remaining: 15.9s
# 566:	learn: 0.1609951	total: 4m 25s	remaining: 15.5s
# 567:	learn: 0.1609918	total: 4m 26s	remaining: 15s
# 568:	learn: 0.1609853	total: 4m 26s	remaining: 14.5s
# 569:	learn: 0.1609846	total: 4m 27s	remaining: 14.1s
# 570:	learn: 0.1609813	total: 4m 28s	remaining: 13.6s
# 571:	learn: 0.1609746	total: 4m 28s	remaining: 13.2s
# 572:	learn: 0.1609680	total: 4m 29s	remaining: 12.7s
# 573:	learn: 0.1609670	total: 4m 29s	remaining: 12.2s
# 574:	learn: 0.1609645	total: 4m 30s	remaining: 11.8s
# 575:	learn: 0.1609610	total: 4m 30s	remaining: 11.3s
# 576:	learn: 0.1609602	total: 4m 31s	remaining: 10.8s
# 577:	learn: 0.1609578	total: 4m 31s	remaining: 10.3s
# 578:	learn: 0.1609568	total: 4m 32s	remaining: 9.88s
# 579:	learn: 0.1609541	total: 4m 32s	remaining: 9.41s
# 580:	learn: 0.1609525	total: 4m 33s	remaining: 8.94s
# 581:	learn: 0.1609516	total: 4m 33s	remaining: 8.47s
# 582:	learn: 0.1609495	total: 4m 34s	remaining: 8s
# 583:	learn: 0.1609474	total: 4m 34s	remaining: 7.53s
# 584:	learn: 0.1609464	total: 4m 35s	remaining: 7.06s
# 585:	learn: 0.1609463	total: 4m 35s	remaining: 6.59s
# 586:	learn: 0.1609446	total: 4m 36s	remaining: 6.12s
# 587:	learn: 0.1609438	total: 4m 36s	remaining: 5.65s
# 588:	learn: 0.1609426	total: 4m 37s	remaining: 5.18s
# 589:	learn: 0.1609388	total: 4m 37s	remaining: 4.71s
# 590:	learn: 0.1609327	total: 4m 38s	remaining: 4.24s
# 591:	learn: 0.1609286	total: 4m 38s	remaining: 3.77s
# 592:	learn: 0.1609243	total: 4m 39s	remaining: 3.29s
# 593:	learn: 0.1609231	total: 4m 39s	remaining: 2.82s
# 594:	learn: 0.1609222	total: 4m 40s	remaining: 2.35s
# 595:	learn: 0.1609210	total: 4m 40s	remaining: 1.88s
# 596:	learn: 0.1609204	total: 4m 41s	remaining: 1.41s
# 597:	learn: 0.1609197	total: 4m 41s	remaining: 942ms
# 598:	learn: 0.1609196	total: 4m 42s	remaining: 471ms
# 599:	learn: 0.1609174	total: 4m 42s	remaining: 0us
# 0:	learn: 0.1694110	total: 611ms	remaining: 6m 6s
# 1:	learn: 0.1693368	total: 1.1s	remaining: 5m 29s
# 2:	learn: 0.1692707	total: 1.71s	remaining: 5m 40s
# 3:	learn: 0.1692052	total: 2.36s	remaining: 5m 51s
# 4:	learn: 0.1691458	total: 2.85s	remaining: 5m 38s
# 5:	learn: 0.1690833	total: 3.28s	remaining: 5m 24s
# 6:	learn: 0.1690290	total: 3.69s	remaining: 5m 12s
# 7:	learn: 0.1689820	total: 4.19s	remaining: 5m 10s
# 8:	learn: 0.1689292	total: 4.64s	remaining: 5m 5s
# 9:	learn: 0.1688794	total: 5.2s	remaining: 5m 6s
# 10:	learn: 0.1688414	total: 5.94s	remaining: 5m 18s
# 11:	learn: 0.1687898	total: 6.5s	remaining: 5m 18s
# 12:	learn: 0.1687480	total: 7.06s	remaining: 5m 18s
# 13:	learn: 0.1687107	total: 7.97s	remaining: 5m 33s
# 14:	learn: 0.1686732	total: 8.85s	remaining: 5m 44s
# 15:	learn: 0.1686376	total: 9.42s	remaining: 5m 43s
# 16:	learn: 0.1685999	total: 9.85s	remaining: 5m 37s
# 17:	learn: 0.1685700	total: 10.3s	remaining: 5m 32s
# 18:	learn: 0.1685523	total: 10.8s	remaining: 5m 29s
# 19:	learn: 0.1685259	total: 11.2s	remaining: 5m 23s
# 20:	learn: 0.1684924	total: 11.6s	remaining: 5m 19s
# 21:	learn: 0.1684551	total: 12s	remaining: 5m 15s
# 22:	learn: 0.1684229	total: 12.4s	remaining: 5m 11s
# 23:	learn: 0.1684076	total: 13s	remaining: 5m 13s
# 24:	learn: 0.1683712	total: 13.6s	remaining: 5m 11s
# 25:	learn: 0.1683545	total: 14.1s	remaining: 5m 10s
# 26:	learn: 0.1683370	total: 14.5s	remaining: 5m 8s
# 27:	learn: 0.1683110	total: 14.9s	remaining: 5m 4s
# 28:	learn: 0.1682984	total: 15.4s	remaining: 5m 2s
# 29:	learn: 0.1682664	total: 15.7s	remaining: 4m 58s
# 30:	learn: 0.1682500	total: 16.4s	remaining: 5m 1s
# 31:	learn: 0.1682251	total: 17.1s	remaining: 5m 3s
# 32:	learn: 0.1682166	total: 17.7s	remaining: 5m 3s
# 33:	learn: 0.1682025	total: 18.2s	remaining: 5m 2s
# 34:	learn: 0.1681894	total: 18.6s	remaining: 4m 59s
# 35:	learn: 0.1681694	total: 19s	remaining: 4m 57s
# 36:	learn: 0.1681540	total: 19.4s	remaining: 4m 55s
# 37:	learn: 0.1681434	total: 19.8s	remaining: 4m 52s
# 38:	learn: 0.1681280	total: 20.2s	remaining: 4m 50s
# 39:	learn: 0.1681202	total: 20.6s	remaining: 4m 48s
# 40:	learn: 0.1681145	total: 21.1s	remaining: 4m 47s
# 41:	learn: 0.1681003	total: 21.5s	remaining: 4m 45s
# 42:	learn: 0.1680860	total: 21.9s	remaining: 4m 43s
# 43:	learn: 0.1680792	total: 22.3s	remaining: 4m 41s
# 44:	learn: 0.1680511	total: 22.6s	remaining: 4m 38s
# 45:	learn: 0.1680305	total: 23s	remaining: 4m 36s
# 46:	learn: 0.1680156	total: 23.3s	remaining: 4m 34s
# 47:	learn: 0.1679987	total: 23.7s	remaining: 4m 32s
# 48:	learn: 0.1679846	total: 24.1s	remaining: 4m 31s
# 49:	learn: 0.1679727	total: 24.5s	remaining: 4m 29s
# 50:	learn: 0.1679609	total: 24.9s	remaining: 4m 28s
# 51:	learn: 0.1679536	total: 25.3s	remaining: 4m 26s
# 52:	learn: 0.1679405	total: 25.7s	remaining: 4m 25s
# 53:	learn: 0.1679191	total: 26s	remaining: 4m 23s
# 54:	learn: 0.1679083	total: 26.4s	remaining: 4m 21s
# 55:	learn: 0.1678960	total: 26.7s	remaining: 4m 19s
# 56:	learn: 0.1678886	total: 27.1s	remaining: 4m 18s
# 57:	learn: 0.1678714	total: 27.4s	remaining: 4m 16s
# 58:	learn: 0.1678602	total: 27.8s	remaining: 4m 14s
# 59:	learn: 0.1678493	total: 28.2s	remaining: 4m 13s
# 60:	learn: 0.1678406	total: 28.6s	remaining: 4m 12s
# 61:	learn: 0.1678215	total: 28.9s	remaining: 4m 11s
# 62:	learn: 0.1678115	total: 29.3s	remaining: 4m 10s
# 63:	learn: 0.1677951	total: 29.8s	remaining: 4m 9s
# 64:	learn: 0.1677862	total: 30.3s	remaining: 4m 9s
# 65:	learn: 0.1677834	total: 30.7s	remaining: 4m 8s
# 66:	learn: 0.1677784	total: 31.2s	remaining: 4m 7s
# 67:	learn: 0.1677667	total: 31.5s	remaining: 4m 6s
# 68:	learn: 0.1677599	total: 31.9s	remaining: 4m 5s
# 69:	learn: 0.1677520	total: 32.4s	remaining: 4m 5s
# 70:	learn: 0.1677375	total: 32.7s	remaining: 4m 3s
# 71:	learn: 0.1677288	total: 33.1s	remaining: 4m 2s
# 72:	learn: 0.1677058	total: 33.4s	remaining: 4m 1s
# 73:	learn: 0.1676970	total: 33.8s	remaining: 4m
# 74:	learn: 0.1676860	total: 34.3s	remaining: 3m 59s
# 75:	learn: 0.1676778	total: 34.7s	remaining: 3m 59s
# 76:	learn: 0.1676719	total: 35.1s	remaining: 3m 58s
# 77:	learn: 0.1676627	total: 35.5s	remaining: 3m 57s
# 78:	learn: 0.1676563	total: 35.8s	remaining: 3m 56s
# 79:	learn: 0.1676520	total: 36.2s	remaining: 3m 55s
# 80:	learn: 0.1676479	total: 36.6s	remaining: 3m 54s
# 81:	learn: 0.1676449	total: 37s	remaining: 3m 53s
# 82:	learn: 0.1676433	total: 37.4s	remaining: 3m 53s
# 83:	learn: 0.1676391	total: 37.8s	remaining: 3m 52s
# 84:	learn: 0.1676300	total: 38.2s	remaining: 3m 51s
# 85:	learn: 0.1676249	total: 38.6s	remaining: 3m 50s
# 86:	learn: 0.1676215	total: 39s	remaining: 3m 50s
# 87:	learn: 0.1676160	total: 39.4s	remaining: 3m 49s
# 88:	learn: 0.1676106	total: 39.8s	remaining: 3m 48s
# 89:	learn: 0.1675996	total: 40.2s	remaining: 3m 47s
# 90:	learn: 0.1675965	total: 40.6s	remaining: 3m 47s
# 91:	learn: 0.1675937	total: 41.1s	remaining: 3m 46s
# 92:	learn: 0.1675898	total: 41.5s	remaining: 3m 45s
# 93:	learn: 0.1675808	total: 41.8s	remaining: 3m 44s
# 94:	learn: 0.1675717	total: 42.2s	remaining: 3m 44s
# 95:	learn: 0.1675689	total: 42.6s	remaining: 3m 43s
# 96:	learn: 0.1675615	total: 42.9s	remaining: 3m 42s
# 97:	learn: 0.1675550	total: 43.4s	remaining: 3m 42s
# 98:	learn: 0.1675523	total: 43.8s	remaining: 3m 41s
# 99:	learn: 0.1675498	total: 44.2s	remaining: 3m 41s
# 100:	learn: 0.1675481	total: 44.7s	remaining: 3m 40s
# 101:	learn: 0.1675458	total: 45.1s	remaining: 3m 40s
# 102:	learn: 0.1675413	total: 45.5s	remaining: 3m 39s
# 103:	learn: 0.1675393	total: 45.9s	remaining: 3m 38s
# 104:	learn: 0.1675361	total: 46.3s	remaining: 3m 38s
# 105:	learn: 0.1675302	total: 46.7s	remaining: 3m 37s
# 106:	learn: 0.1675255	total: 47.1s	remaining: 3m 36s
# 107:	learn: 0.1675231	total: 47.5s	remaining: 3m 36s
# 108:	learn: 0.1675142	total: 47.8s	remaining: 3m 35s
# 109:	learn: 0.1675114	total: 48.3s	remaining: 3m 34s
# 110:	learn: 0.1675078	total: 48.7s	remaining: 3m 34s
# 111:	learn: 0.1675052	total: 49.1s	remaining: 3m 33s
# 112:	learn: 0.1675049	total: 49.5s	remaining: 3m 33s
# 113:	learn: 0.1675029	total: 49.9s	remaining: 3m 32s
# 114:	learn: 0.1675002	total: 50.3s	remaining: 3m 32s
# 115:	learn: 0.1674960	total: 50.8s	remaining: 3m 31s
# 116:	learn: 0.1674930	total: 51.2s	remaining: 3m 31s
# 117:	learn: 0.1674900	total: 51.6s	remaining: 3m 30s
# 118:	learn: 0.1674882	total: 52s	remaining: 3m 30s
# 119:	learn: 0.1674848	total: 52.5s	remaining: 3m 29s
# 120:	learn: 0.1674744	total: 52.8s	remaining: 3m 29s
# 121:	learn: 0.1674700	total: 53.3s	remaining: 3m 28s
# 122:	learn: 0.1674581	total: 53.6s	remaining: 3m 27s
# 123:	learn: 0.1674519	total: 54s	remaining: 3m 27s
# 124:	learn: 0.1674494	total: 54.4s	remaining: 3m 26s
# 125:	learn: 0.1674377	total: 54.8s	remaining: 3m 25s
# 126:	learn: 0.1674352	total: 55.2s	remaining: 3m 25s
# 127:	learn: 0.1674328	total: 55.6s	remaining: 3m 25s
# 128:	learn: 0.1674320	total: 56s	remaining: 3m 24s
# 129:	learn: 0.1674273	total: 56.4s	remaining: 3m 23s
# 130:	learn: 0.1674254	total: 56.8s	remaining: 3m 23s
# 131:	learn: 0.1674238	total: 57.2s	remaining: 3m 22s
# 132:	learn: 0.1674194	total: 57.6s	remaining: 3m 22s
# 133:	learn: 0.1674171	total: 58s	remaining: 3m 21s
# 134:	learn: 0.1674152	total: 58.5s	remaining: 3m 21s
# 135:	learn: 0.1674124	total: 58.9s	remaining: 3m 21s
# 136:	learn: 0.1674063	total: 59.3s	remaining: 3m 20s
# 137:	learn: 0.1674019	total: 59.7s	remaining: 3m 19s
# 138:	learn: 0.1673935	total: 1m	remaining: 3m 19s
# 139:	learn: 0.1673922	total: 1m	remaining: 3m 19s
# 140:	learn: 0.1673800	total: 1m 1s	remaining: 3m 18s
# 141:	learn: 0.1673761	total: 1m 1s	remaining: 3m 18s
# 142:	learn: 0.1673742	total: 1m 1s	remaining: 3m 18s
# 143:	learn: 0.1673624	total: 1m 2s	remaining: 3m 17s
# 144:	learn: 0.1673577	total: 1m 2s	remaining: 3m 17s
# 145:	learn: 0.1673449	total: 1m 3s	remaining: 3m 16s
# 146:	learn: 0.1673437	total: 1m 3s	remaining: 3m 15s
# 147:	learn: 0.1673417	total: 1m 3s	remaining: 3m 15s
# 148:	learn: 0.1673391	total: 1m 4s	remaining: 3m 14s
# 149:	learn: 0.1673351	total: 1m 4s	remaining: 3m 14s
# 150:	learn: 0.1673334	total: 1m 5s	remaining: 3m 13s
# 151:	learn: 0.1673300	total: 1m 5s	remaining: 3m 13s
# 152:	learn: 0.1673280	total: 1m 5s	remaining: 3m 12s
# 153:	learn: 0.1673270	total: 1m 6s	remaining: 3m 12s
# 154:	learn: 0.1673218	total: 1m 6s	remaining: 3m 11s
# 155:	learn: 0.1673161	total: 1m 7s	remaining: 3m 11s
# 156:	learn: 0.1673065	total: 1m 7s	remaining: 3m 10s
# 157:	learn: 0.1673011	total: 1m 7s	remaining: 3m 9s
# 158:	learn: 0.1672876	total: 1m 8s	remaining: 3m 9s
# 159:	learn: 0.1672817	total: 1m 8s	remaining: 3m 8s
# 160:	learn: 0.1672747	total: 1m 9s	remaining: 3m 8s
# 161:	learn: 0.1672690	total: 1m 9s	remaining: 3m 7s
# 162:	learn: 0.1672689	total: 1m 9s	remaining: 3m 7s
# 163:	learn: 0.1672634	total: 1m 10s	remaining: 3m 6s
# 164:	learn: 0.1672595	total: 1m 10s	remaining: 3m 6s
# 165:	learn: 0.1672591	total: 1m 11s	remaining: 3m 5s
# 166:	learn: 0.1672589	total: 1m 11s	remaining: 3m 5s
# 167:	learn: 0.1672550	total: 1m 11s	remaining: 3m 4s
# 168:	learn: 0.1672525	total: 1m 12s	remaining: 3m 4s
# 169:	learn: 0.1672501	total: 1m 12s	remaining: 3m 3s
# 170:	learn: 0.1672450	total: 1m 13s	remaining: 3m 3s
# 171:	learn: 0.1672410	total: 1m 13s	remaining: 3m 2s
# 172:	learn: 0.1672392	total: 1m 13s	remaining: 3m 2s
# 173:	learn: 0.1672376	total: 1m 14s	remaining: 3m 1s
# 174:	learn: 0.1672349	total: 1m 14s	remaining: 3m 1s
# 175:	learn: 0.1672305	total: 1m 15s	remaining: 3m 1s
# 176:	learn: 0.1672241	total: 1m 15s	remaining: 3m
# 177:	learn: 0.1672224	total: 1m 15s	remaining: 2m 59s
# 178:	learn: 0.1672196	total: 1m 16s	remaining: 2m 59s
# 179:	learn: 0.1672133	total: 1m 16s	remaining: 2m 58s
# 180:	learn: 0.1672100	total: 1m 17s	remaining: 2m 58s
# 181:	learn: 0.1672016	total: 1m 17s	remaining: 2m 57s
# 182:	learn: 0.1671981	total: 1m 17s	remaining: 2m 57s
# 183:	learn: 0.1671954	total: 1m 18s	remaining: 2m 57s
# 184:	learn: 0.1671944	total: 1m 18s	remaining: 2m 56s
# 185:	learn: 0.1671845	total: 1m 19s	remaining: 2m 56s
# 186:	learn: 0.1671811	total: 1m 19s	remaining: 2m 55s
# 187:	learn: 0.1671708	total: 1m 19s	remaining: 2m 55s
# 188:	learn: 0.1671686	total: 1m 20s	remaining: 2m 54s
# 189:	learn: 0.1671669	total: 1m 20s	remaining: 2m 54s
# 190:	learn: 0.1671650	total: 1m 21s	remaining: 2m 53s
# 191:	learn: 0.1671623	total: 1m 21s	remaining: 2m 53s
# 192:	learn: 0.1671577	total: 1m 22s	remaining: 2m 52s
# 193:	learn: 0.1671563	total: 1m 22s	remaining: 2m 52s
# 194:	learn: 0.1671547	total: 1m 22s	remaining: 2m 52s
# 195:	learn: 0.1671400	total: 1m 23s	remaining: 2m 51s
# 196:	learn: 0.1671359	total: 1m 23s	remaining: 2m 51s
# 197:	learn: 0.1671313	total: 1m 24s	remaining: 2m 50s
# 198:	learn: 0.1671240	total: 1m 24s	remaining: 2m 50s
# 199:	learn: 0.1671194	total: 1m 24s	remaining: 2m 49s
# 200:	learn: 0.1671157	total: 1m 25s	remaining: 2m 49s
# 201:	learn: 0.1671136	total: 1m 25s	remaining: 2m 48s
# 202:	learn: 0.1671118	total: 1m 26s	remaining: 2m 48s
# 203:	learn: 0.1671114	total: 1m 26s	remaining: 2m 47s
# 204:	learn: 0.1671093	total: 1m 26s	remaining: 2m 47s
# 205:	learn: 0.1671078	total: 1m 27s	remaining: 2m 46s
# 206:	learn: 0.1671052	total: 1m 27s	remaining: 2m 46s
# 207:	learn: 0.1671014	total: 1m 28s	remaining: 2m 45s
# 208:	learn: 0.1670905	total: 1m 28s	remaining: 2m 45s
# 209:	learn: 0.1670868	total: 1m 28s	remaining: 2m 45s
# 210:	learn: 0.1670847	total: 1m 29s	remaining: 2m 44s
# 211:	learn: 0.1670805	total: 1m 29s	remaining: 2m 44s
# 212:	learn: 0.1670678	total: 1m 30s	remaining: 2m 43s
# 213:	learn: 0.1670656	total: 1m 30s	remaining: 2m 43s
# 214:	learn: 0.1670616	total: 1m 30s	remaining: 2m 42s
# 215:	learn: 0.1670576	total: 1m 31s	remaining: 2m 42s
# 216:	learn: 0.1670569	total: 1m 31s	remaining: 2m 41s
# 217:	learn: 0.1670469	total: 1m 31s	remaining: 2m 41s
# 218:	learn: 0.1670451	total: 1m 32s	remaining: 2m 40s
# 219:	learn: 0.1670435	total: 1m 32s	remaining: 2m 40s
# 220:	learn: 0.1670388	total: 1m 33s	remaining: 2m 39s
# 221:	learn: 0.1670306	total: 1m 33s	remaining: 2m 39s
# 222:	learn: 0.1670267	total: 1m 33s	remaining: 2m 38s
# 223:	learn: 0.1670237	total: 1m 34s	remaining: 2m 38s
# 224:	learn: 0.1670216	total: 1m 34s	remaining: 2m 38s
# 225:	learn: 0.1670185	total: 1m 35s	remaining: 2m 37s
# 226:	learn: 0.1670145	total: 1m 35s	remaining: 2m 37s
# 227:	learn: 0.1670124	total: 1m 36s	remaining: 2m 36s
# 228:	learn: 0.1670028	total: 1m 36s	remaining: 2m 36s
# 229:	learn: 0.1670017	total: 1m 36s	remaining: 2m 35s
# 230:	learn: 0.1669980	total: 1m 37s	remaining: 2m 35s
# 231:	learn: 0.1669937	total: 1m 37s	remaining: 2m 34s
# 232:	learn: 0.1669902	total: 1m 38s	remaining: 2m 34s
# 233:	learn: 0.1669878	total: 1m 38s	remaining: 2m 34s
# 234:	learn: 0.1669869	total: 1m 38s	remaining: 2m 33s
# 235:	learn: 0.1669863	total: 1m 39s	remaining: 2m 33s
# 236:	learn: 0.1669819	total: 1m 39s	remaining: 2m 32s
# 237:	learn: 0.1669776	total: 1m 40s	remaining: 2m 32s
# 238:	learn: 0.1669759	total: 1m 40s	remaining: 2m 31s
# 239:	learn: 0.1669720	total: 1m 40s	remaining: 2m 31s
# 240:	learn: 0.1669689	total: 1m 41s	remaining: 2m 31s
# 241:	learn: 0.1669643	total: 1m 41s	remaining: 2m 30s
# 242:	learn: 0.1669629	total: 1m 42s	remaining: 2m 29s
# 243:	learn: 0.1669585	total: 1m 42s	remaining: 2m 29s
# 244:	learn: 0.1669570	total: 1m 42s	remaining: 2m 29s
# 245:	learn: 0.1669519	total: 1m 43s	remaining: 2m 28s
# 246:	learn: 0.1669505	total: 1m 43s	remaining: 2m 28s
# 247:	learn: 0.1669483	total: 1m 44s	remaining: 2m 27s
# 248:	learn: 0.1669412	total: 1m 44s	remaining: 2m 27s
# 249:	learn: 0.1669377	total: 1m 44s	remaining: 2m 26s
# 250:	learn: 0.1669374	total: 1m 45s	remaining: 2m 26s
# 251:	learn: 0.1669367	total: 1m 45s	remaining: 2m 26s
# 252:	learn: 0.1669346	total: 1m 46s	remaining: 2m 25s
# 253:	learn: 0.1669310	total: 1m 46s	remaining: 2m 25s
# 254:	learn: 0.1669289	total: 1m 46s	remaining: 2m 24s
# 255:	learn: 0.1669193	total: 1m 47s	remaining: 2m 24s
# 256:	learn: 0.1669175	total: 1m 47s	remaining: 2m 23s
# 257:	learn: 0.1669140	total: 1m 48s	remaining: 2m 23s
# 258:	learn: 0.1669068	total: 1m 48s	remaining: 2m 22s
# 259:	learn: 0.1669037	total: 1m 48s	remaining: 2m 22s
# 260:	learn: 0.1669025	total: 1m 49s	remaining: 2m 22s
# 261:	learn: 0.1669007	total: 1m 49s	remaining: 2m 21s
# 262:	learn: 0.1668965	total: 1m 50s	remaining: 2m 21s
# 263:	learn: 0.1668931	total: 1m 50s	remaining: 2m 20s
# 264:	learn: 0.1668895	total: 1m 51s	remaining: 2m 20s
# 265:	learn: 0.1668874	total: 1m 51s	remaining: 2m 20s
# 266:	learn: 0.1668814	total: 1m 51s	remaining: 2m 19s
# 267:	learn: 0.1668784	total: 1m 52s	remaining: 2m 19s
# 268:	learn: 0.1668734	total: 1m 52s	remaining: 2m 18s
# 269:	learn: 0.1668719	total: 1m 53s	remaining: 2m 18s
# 270:	learn: 0.1668636	total: 1m 53s	remaining: 2m 17s
# 271:	learn: 0.1668581	total: 1m 53s	remaining: 2m 17s
# 272:	learn: 0.1668567	total: 1m 54s	remaining: 2m 16s
# 273:	learn: 0.1668534	total: 1m 54s	remaining: 2m 16s
# 274:	learn: 0.1668511	total: 1m 55s	remaining: 2m 16s
# 275:	learn: 0.1668501	total: 1m 55s	remaining: 2m 15s
# 276:	learn: 0.1668483	total: 1m 56s	remaining: 2m 15s
# 277:	learn: 0.1668473	total: 1m 56s	remaining: 2m 14s
# 278:	learn: 0.1668367	total: 1m 56s	remaining: 2m 14s
# 279:	learn: 0.1668292	total: 1m 57s	remaining: 2m 13s
# 280:	learn: 0.1668285	total: 1m 57s	remaining: 2m 13s
# 281:	learn: 0.1668257	total: 1m 58s	remaining: 2m 13s
# 282:	learn: 0.1668237	total: 1m 58s	remaining: 2m 12s
# 283:	learn: 0.1668126	total: 1m 58s	remaining: 2m 12s
# 284:	learn: 0.1668015	total: 1m 59s	remaining: 2m 11s
# 285:	learn: 0.1667977	total: 1m 59s	remaining: 2m 11s
# 286:	learn: 0.1667935	total: 2m	remaining: 2m 10s
# 287:	learn: 0.1667923	total: 2m	remaining: 2m 10s
# 288:	learn: 0.1667844	total: 2m	remaining: 2m 10s
# 289:	learn: 0.1667832	total: 2m 1s	remaining: 2m 9s
# 290:	learn: 0.1667824	total: 2m 1s	remaining: 2m 9s
# 291:	learn: 0.1667813	total: 2m 2s	remaining: 2m 8s
# 292:	learn: 0.1667802	total: 2m 2s	remaining: 2m 8s
# 293:	learn: 0.1667641	total: 2m 2s	remaining: 2m 7s
# 294:	learn: 0.1667626	total: 2m 3s	remaining: 2m 7s
# 295:	learn: 0.1667591	total: 2m 3s	remaining: 2m 7s
# 296:	learn: 0.1667532	total: 2m 4s	remaining: 2m 6s
# 297:	learn: 0.1667483	total: 2m 4s	remaining: 2m 6s
# 298:	learn: 0.1667471	total: 2m 4s	remaining: 2m 5s
# 299:	learn: 0.1667363	total: 2m 5s	remaining: 2m 5s
# 300:	learn: 0.1667332	total: 2m 5s	remaining: 2m 4s
# 301:	learn: 0.1667294	total: 2m 6s	remaining: 2m 4s
# 302:	learn: 0.1667271	total: 2m 6s	remaining: 2m 3s
# 303:	learn: 0.1667138	total: 2m 6s	remaining: 2m 3s
# 304:	learn: 0.1667131	total: 2m 7s	remaining: 2m 3s
# 305:	learn: 0.1667116	total: 2m 7s	remaining: 2m 2s
# ...
# 104:	learn: 0.1608160	total: 48.5s	remaining: 3m 48s
# 105:	learn: 0.1608103	total: 49s	remaining: 3m 48s
# 106:	learn: 0.1608068	total: 49.6s	remaining: 3m 48s
# 107:	learn: 0.1607963	total: 50.2s	remaining: 3m 48s
# 108:	learn: 0.1607860	total: 50.8s	remaining: 3m 48s
# 109:	learn: 0.1607765	total: 51.4s	remaining: 3m 49s
# 110:	learn: 0.1607745	total: 52.5s	remaining: 3m 51s
# 111:	learn: 0.1607728	total: 53.3s	remaining: 3m 52s
# 112:	learn: 0.1607691	total: 54.4s	remaining: 3m 54s
# 113:	learn: 0.1607641	total: 55.4s	remaining: 3m 56s
# 114:	learn: 0.1607623	total: 56.3s	remaining: 3m 57s
# 115:	learn: 0.1607579	total: 56.9s	remaining: 3m 57s
# 116:	learn: 0.1607545	total: 57.6s	remaining: 3m 57s
# 117:	learn: 0.1607473	total: 58.1s	remaining: 3m 57s
# 118:	learn: 0.1607459	total: 58.5s	remaining: 3m 56s
# 119:	learn: 0.1607342	total: 59s	remaining: 3m 56s
# 120:	learn: 0.1607308	total: 59.5s	remaining: 3m 55s
# 121:	learn: 0.1607276	total: 1m	remaining: 3m 55s
# 122:	learn: 0.1607249	total: 1m	remaining: 3m 55s
# 123:	learn: 0.1607181	total: 1m 1s	remaining: 3m 55s
# 124:	learn: 0.1607153	total: 1m 1s	remaining: 3m 54s
# 125:	learn: 0.1607128	total: 1m 2s	remaining: 3m 53s
# 126:	learn: 0.1607068	total: 1m 2s	remaining: 3m 54s
# 127:	learn: 0.1607042	total: 1m 3s	remaining: 3m 54s
# 128:	learn: 0.1606994	total: 1m 4s	remaining: 3m 53s
# 129:	learn: 0.1606964	total: 1m 4s	remaining: 3m 54s
# 130:	learn: 0.1606943	total: 1m 5s	remaining: 3m 54s
# 131:	learn: 0.1606919	total: 1m 5s	remaining: 3m 53s
# 132:	learn: 0.1606799	total: 1m 6s	remaining: 3m 52s
# 133:	learn: 0.1606787	total: 1m 6s	remaining: 3m 52s
# 134:	learn: 0.1606747	total: 1m 7s	remaining: 3m 52s
# 135:	learn: 0.1606658	total: 1m 7s	remaining: 3m 51s
# 136:	learn: 0.1606642	total: 1m 8s	remaining: 3m 51s
# 137:	learn: 0.1606574	total: 1m 9s	remaining: 3m 51s
# 138:	learn: 0.1606536	total: 1m 9s	remaining: 3m 51s
# 139:	learn: 0.1606492	total: 1m 11s	remaining: 3m 53s
# 140:	learn: 0.1606391	total: 1m 12s	remaining: 3m 55s
# 141:	learn: 0.1606384	total: 1m 13s	remaining: 3m 55s
# 142:	learn: 0.1606351	total: 1m 13s	remaining: 3m 56s
# 143:	learn: 0.1606331	total: 1m 14s	remaining: 3m 56s
# 144:	learn: 0.1606308	total: 1m 15s	remaining: 3m 57s
# 145:	learn: 0.1606237	total: 1m 16s	remaining: 3m 57s
# 146:	learn: 0.1606224	total: 1m 17s	remaining: 3m 58s
# 147:	learn: 0.1606184	total: 1m 18s	remaining: 3m 58s
# 148:	learn: 0.1606110	total: 1m 19s	remaining: 3m 59s
# 149:	learn: 0.1606037	total: 1m 19s	remaining: 3m 59s
# 150:	learn: 0.1606000	total: 1m 20s	remaining: 3m 59s
# 151:	learn: 0.1605989	total: 1m 21s	remaining: 3m 58s
# 152:	learn: 0.1605956	total: 1m 21s	remaining: 3m 58s
# 153:	learn: 0.1605954	total: 1m 22s	remaining: 3m 58s
# 154:	learn: 0.1605915	total: 1m 22s	remaining: 3m 57s
# 155:	learn: 0.1605893	total: 1m 23s	remaining: 3m 56s
# 156:	learn: 0.1605850	total: 1m 23s	remaining: 3m 56s
# 157:	learn: 0.1605797	total: 1m 24s	remaining: 3m 55s
# 158:	learn: 0.1605731	total: 1m 24s	remaining: 3m 54s
# 159:	learn: 0.1605698	total: 1m 25s	remaining: 3m 54s
# 160:	learn: 0.1605491	total: 1m 25s	remaining: 3m 53s
# 161:	learn: 0.1605435	total: 1m 26s	remaining: 3m 52s
# 162:	learn: 0.1605350	total: 1m 26s	remaining: 3m 51s
# 163:	learn: 0.1605327	total: 1m 27s	remaining: 3m 51s
# 164:	learn: 0.1605313	total: 1m 27s	remaining: 3m 50s
# 165:	learn: 0.1605267	total: 1m 28s	remaining: 3m 50s
# 166:	learn: 0.1605208	total: 1m 28s	remaining: 3m 49s
# 167:	learn: 0.1605163	total: 1m 28s	remaining: 3m 48s
# 168:	learn: 0.1605139	total: 1m 29s	remaining: 3m 48s
# 169:	learn: 0.1605121	total: 1m 29s	remaining: 3m 47s
# 170:	learn: 0.1605006	total: 1m 30s	remaining: 3m 46s
# 171:	learn: 0.1604948	total: 1m 30s	remaining: 3m 46s
# 172:	learn: 0.1604859	total: 1m 31s	remaining: 3m 45s
# 173:	learn: 0.1604729	total: 1m 31s	remaining: 3m 44s
# 174:	learn: 0.1604720	total: 1m 32s	remaining: 3m 44s
# 175:	learn: 0.1604598	total: 1m 32s	remaining: 3m 43s
# 176:	learn: 0.1604578	total: 1m 33s	remaining: 3m 43s
# 177:	learn: 0.1604535	total: 1m 34s	remaining: 3m 42s
# 178:	learn: 0.1604482	total: 1m 34s	remaining: 3m 42s
# 179:	learn: 0.1604452	total: 1m 35s	remaining: 3m 41s
# 180:	learn: 0.1604414	total: 1m 35s	remaining: 3m 41s
# 181:	learn: 0.1604290	total: 1m 36s	remaining: 3m 41s
# 182:	learn: 0.1604242	total: 1m 36s	remaining: 3m 40s
# 183:	learn: 0.1604230	total: 1m 37s	remaining: 3m 40s
# 184:	learn: 0.1604207	total: 1m 38s	remaining: 3m 40s
# 185:	learn: 0.1604176	total: 1m 38s	remaining: 3m 40s
# 186:	learn: 0.1604087	total: 1m 39s	remaining: 3m 39s
# 187:	learn: 0.1603954	total: 1m 39s	remaining: 3m 38s
# 188:	learn: 0.1603825	total: 1m 40s	remaining: 3m 38s
# 189:	learn: 0.1603762	total: 1m 40s	remaining: 3m 37s
# 190:	learn: 0.1603754	total: 1m 41s	remaining: 3m 37s
# 191:	learn: 0.1603734	total: 1m 41s	remaining: 3m 36s
# 192:	learn: 0.1603717	total: 1m 42s	remaining: 3m 35s
# 193:	learn: 0.1603693	total: 1m 42s	remaining: 3m 35s
# 194:	learn: 0.1603643	total: 1m 43s	remaining: 3m 34s
# 195:	learn: 0.1603605	total: 1m 43s	remaining: 3m 34s
# 196:	learn: 0.1603560	total: 1m 44s	remaining: 3m 33s
# 197:	learn: 0.1603515	total: 1m 44s	remaining: 3m 32s
# 198:	learn: 0.1603488	total: 1m 45s	remaining: 3m 32s
# 199:	learn: 0.1603443	total: 1m 45s	remaining: 3m 31s
# 200:	learn: 0.1603401	total: 1m 46s	remaining: 3m 30s
# 201:	learn: 0.1603349	total: 1m 46s	remaining: 3m 30s
# 202:	learn: 0.1603334	total: 1m 47s	remaining: 3m 29s
# 203:	learn: 0.1603318	total: 1m 47s	remaining: 3m 28s
# 204:	learn: 0.1603283	total: 1m 48s	remaining: 3m 28s
# 205:	learn: 0.1603269	total: 1m 48s	remaining: 3m 27s
# 206:	learn: 0.1603264	total: 1m 49s	remaining: 3m 27s
# 207:	learn: 0.1603193	total: 1m 49s	remaining: 3m 26s
# 208:	learn: 0.1603165	total: 1m 49s	remaining: 3m 25s
# 209:	learn: 0.1603125	total: 1m 50s	remaining: 3m 24s
# 210:	learn: 0.1603088	total: 1m 50s	remaining: 3m 23s
# 211:	learn: 0.1603067	total: 1m 51s	remaining: 3m 23s
# 212:	learn: 0.1602987	total: 1m 51s	remaining: 3m 22s
# 213:	learn: 0.1602915	total: 1m 51s	remaining: 3m 21s
# 214:	learn: 0.1602883	total: 1m 52s	remaining: 3m 21s
# 215:	learn: 0.1602846	total: 1m 52s	remaining: 3m 20s
# 216:	learn: 0.1602810	total: 1m 53s	remaining: 3m 19s
# 217:	learn: 0.1602786	total: 1m 53s	remaining: 3m 19s
# 218:	learn: 0.1602777	total: 1m 54s	remaining: 3m 18s
# 219:	learn: 0.1602750	total: 1m 54s	remaining: 3m 17s
# 220:	learn: 0.1602692	total: 1m 54s	remaining: 3m 17s
# 221:	learn: 0.1602649	total: 1m 55s	remaining: 3m 16s
# 222:	learn: 0.1602556	total: 1m 55s	remaining: 3m 15s
# 223:	learn: 0.1602534	total: 1m 56s	remaining: 3m 14s
# 224:	learn: 0.1602507	total: 1m 56s	remaining: 3m 14s
# 225:	learn: 0.1602431	total: 1m 56s	remaining: 3m 13s
# 226:	learn: 0.1602418	total: 1m 57s	remaining: 3m 12s
# 227:	learn: 0.1602367	total: 1m 57s	remaining: 3m 12s
# 228:	learn: 0.1602315	total: 1m 58s	remaining: 3m 11s
# 229:	learn: 0.1602244	total: 1m 58s	remaining: 3m 10s
# 230:	learn: 0.1602201	total: 1m 59s	remaining: 3m 10s
# 231:	learn: 0.1602124	total: 1m 59s	remaining: 3m 9s
# 232:	learn: 0.1602108	total: 1m 59s	remaining: 3m 8s
# 233:	learn: 0.1602097	total: 2m	remaining: 3m 8s
# 234:	learn: 0.1602089	total: 2m	remaining: 3m 7s
# 235:	learn: 0.1602041	total: 2m 1s	remaining: 3m 7s
# 236:	learn: 0.1601972	total: 2m 1s	remaining: 3m 6s
# 237:	learn: 0.1601891	total: 2m 2s	remaining: 3m 5s
# 238:	learn: 0.1601775	total: 2m 2s	remaining: 3m 5s
# 239:	learn: 0.1601741	total: 2m 2s	remaining: 3m 4s
# 240:	learn: 0.1601725	total: 2m 3s	remaining: 3m 3s
# 241:	learn: 0.1601702	total: 2m 3s	remaining: 3m 3s
# 242:	learn: 0.1601635	total: 2m 4s	remaining: 3m 2s
# 243:	learn: 0.1601609	total: 2m 4s	remaining: 3m 2s
# 244:	learn: 0.1601570	total: 2m 5s	remaining: 3m 1s
# 245:	learn: 0.1601514	total: 2m 5s	remaining: 3m 1s
# 246:	learn: 0.1601416	total: 2m 6s	remaining: 3m
# 247:	learn: 0.1601375	total: 2m 6s	remaining: 3m
# 248:	learn: 0.1601360	total: 2m 7s	remaining: 2m 59s
# 249:	learn: 0.1601350	total: 2m 7s	remaining: 2m 58s
# 250:	learn: 0.1601296	total: 2m 8s	remaining: 2m 58s
# 251:	learn: 0.1601268	total: 2m 8s	remaining: 2m 57s
# 252:	learn: 0.1601224	total: 2m 9s	remaining: 2m 56s
# 253:	learn: 0.1601132	total: 2m 9s	remaining: 2m 56s
# 254:	learn: 0.1601125	total: 2m 9s	remaining: 2m 55s
# 255:	learn: 0.1601082	total: 2m 10s	remaining: 2m 55s
# 256:	learn: 0.1601056	total: 2m 10s	remaining: 2m 54s
# 257:	learn: 0.1601018	total: 2m 11s	remaining: 2m 53s
# 258:	learn: 0.1600959	total: 2m 11s	remaining: 2m 53s
# 259:	learn: 0.1600933	total: 2m 11s	remaining: 2m 52s
# 260:	learn: 0.1600927	total: 2m 12s	remaining: 2m 51s
# 261:	learn: 0.1600856	total: 2m 12s	remaining: 2m 51s
# 262:	learn: 0.1600842	total: 2m 13s	remaining: 2m 50s
# 263:	learn: 0.1600741	total: 2m 13s	remaining: 2m 49s
# 264:	learn: 0.1600639	total: 2m 14s	remaining: 2m 49s
# 265:	learn: 0.1600594	total: 2m 14s	remaining: 2m 48s
# 266:	learn: 0.1600571	total: 2m 14s	remaining: 2m 48s
# 267:	learn: 0.1600505	total: 2m 15s	remaining: 2m 47s
# 268:	learn: 0.1600437	total: 2m 15s	remaining: 2m 46s
# 269:	learn: 0.1600355	total: 2m 16s	remaining: 2m 46s
# 270:	learn: 0.1600250	total: 2m 16s	remaining: 2m 45s
# 271:	learn: 0.1600204	total: 2m 16s	remaining: 2m 45s
# 272:	learn: 0.1600162	total: 2m 17s	remaining: 2m 44s
# 273:	learn: 0.1600161	total: 2m 17s	remaining: 2m 43s
# 274:	learn: 0.1600119	total: 2m 18s	remaining: 2m 43s
# 275:	learn: 0.1600100	total: 2m 18s	remaining: 2m 42s
# 276:	learn: 0.1600093	total: 2m 19s	remaining: 2m 42s
# 277:	learn: 0.1600043	total: 2m 19s	remaining: 2m 41s
# 278:	learn: 0.1600031	total: 2m 19s	remaining: 2m 41s
# 279:	learn: 0.1599997	total: 2m 20s	remaining: 2m 40s
# 280:	learn: 0.1599899	total: 2m 20s	remaining: 2m 39s
# 281:	learn: 0.1599887	total: 2m 21s	remaining: 2m 39s
# 282:	learn: 0.1599822	total: 2m 21s	remaining: 2m 38s
# 283:	learn: 0.1599744	total: 2m 21s	remaining: 2m 37s
# 284:	learn: 0.1599723	total: 2m 22s	remaining: 2m 37s
# 285:	learn: 0.1599718	total: 2m 22s	remaining: 2m 36s
# 286:	learn: 0.1599692	total: 2m 23s	remaining: 2m 35s
# 287:	learn: 0.1599650	total: 2m 23s	remaining: 2m 35s
# 288:	learn: 0.1599569	total: 2m 23s	remaining: 2m 34s
# 289:	learn: 0.1599475	total: 2m 24s	remaining: 2m 34s
# 290:	learn: 0.1599427	total: 2m 24s	remaining: 2m 33s
# 291:	learn: 0.1599345	total: 2m 24s	remaining: 2m 32s
# 292:	learn: 0.1599313	total: 2m 25s	remaining: 2m 32s
# 293:	learn: 0.1599289	total: 2m 25s	remaining: 2m 31s
# 294:	learn: 0.1599194	total: 2m 26s	remaining: 2m 31s
# 295:	learn: 0.1599157	total: 2m 26s	remaining: 2m 30s
# 296:	learn: 0.1599145	total: 2m 26s	remaining: 2m 29s
# 297:	learn: 0.1599094	total: 2m 27s	remaining: 2m 29s
# 298:	learn: 0.1599045	total: 2m 27s	remaining: 2m 28s
# 299:	learn: 0.1599028	total: 2m 28s	remaining: 2m 28s
# 300:	learn: 0.1599013	total: 2m 28s	remaining: 2m 27s
# 301:	learn: 0.1598998	total: 2m 28s	remaining: 2m 26s
# 302:	learn: 0.1598943	total: 2m 29s	remaining: 2m 26s
# 303:	learn: 0.1598922	total: 2m 29s	remaining: 2m 25s
# 304:	learn: 0.1598832	total: 2m 30s	remaining: 2m 25s
# 305:	learn: 0.1598812	total: 2m 30s	remaining: 2m 24s
# 306:	learn: 0.1598782	total: 2m 30s	remaining: 2m 24s
# 307:	learn: 0.1598723	total: 2m 31s	remaining: 2m 23s
# 308:	learn: 0.1598694	total: 2m 31s	remaining: 2m 22s
# 309:	learn: 0.1598647	total: 2m 32s	remaining: 2m 22s
# 310:	learn: 0.1598634	total: 2m 32s	remaining: 2m 21s
# 311:	learn: 0.1598618	total: 2m 33s	remaining: 2m 21s
# 312:	learn: 0.1598585	total: 2m 33s	remaining: 2m 20s
# 313:	learn: 0.1598576	total: 2m 33s	remaining: 2m 20s
# 314:	learn: 0.1598560	total: 2m 34s	remaining: 2m 19s
# 315:	learn: 0.1598558	total: 2m 34s	remaining: 2m 19s
# 316:	learn: 0.1598529	total: 2m 35s	remaining: 2m 18s
# 317:	learn: 0.1598498	total: 2m 35s	remaining: 2m 17s
# 318:	learn: 0.1598488	total: 2m 35s	remaining: 2m 17s
# 319:	learn: 0.1598468	total: 2m 36s	remaining: 2m 16s
# 320:	learn: 0.1598385	total: 2m 36s	remaining: 2m 16s
# 321:	learn: 0.1598335	total: 2m 37s	remaining: 2m 15s
# 322:	learn: 0.1598311	total: 2m 37s	remaining: 2m 15s
# 323:	learn: 0.1598286	total: 2m 37s	remaining: 2m 14s
# 324:	learn: 0.1598227	total: 2m 38s	remaining: 2m 13s
# 325:	learn: 0.1598203	total: 2m 38s	remaining: 2m 13s
# 326:	learn: 0.1598149	total: 2m 39s	remaining: 2m 12s
# 327:	learn: 0.1598102	total: 2m 39s	remaining: 2m 12s
# 328:	learn: 0.1598092	total: 2m 40s	remaining: 2m 11s
# 329:	learn: 0.1598067	total: 2m 40s	remaining: 2m 11s
# 330:	learn: 0.1598050	total: 2m 40s	remaining: 2m 10s
# 331:	learn: 0.1598040	total: 2m 41s	remaining: 2m 10s
# 332:	learn: 0.1597974	total: 2m 41s	remaining: 2m 9s
# 333:	learn: 0.1597965	total: 2m 42s	remaining: 2m 9s
# 334:	learn: 0.1597947	total: 2m 42s	remaining: 2m 8s
# 335:	learn: 0.1597875	total: 2m 42s	remaining: 2m 7s
# 336:	learn: 0.1597825	total: 2m 43s	remaining: 2m 7s
# 337:	learn: 0.1597820	total: 2m 43s	remaining: 2m 6s
# 338:	learn: 0.1597802	total: 2m 44s	remaining: 2m 6s
# 339:	learn: 0.1597736	total: 2m 44s	remaining: 2m 5s
# 340:	learn: 0.1597734	total: 2m 44s	remaining: 2m 5s
# 341:	learn: 0.1597666	total: 2m 45s	remaining: 2m 4s
# 342:	learn: 0.1597620	total: 2m 45s	remaining: 2m 4s
# 343:	learn: 0.1597605	total: 2m 46s	remaining: 2m 3s
# 344:	learn: 0.1597568	total: 2m 46s	remaining: 2m 3s
# 345:	learn: 0.1597546	total: 2m 47s	remaining: 2m 2s
# 346:	learn: 0.1597528	total: 2m 47s	remaining: 2m 2s
# 347:	learn: 0.1597484	total: 2m 47s	remaining: 2m 1s
# 348:	learn: 0.1597467	total: 2m 48s	remaining: 2m 1s
# 349:	learn: 0.1597450	total: 2m 48s	remaining: 2m
# 350:	learn: 0.1597420	total: 2m 49s	remaining: 2m
# 351:	learn: 0.1597407	total: 2m 49s	remaining: 1m 59s
# 352:	learn: 0.1597392	total: 2m 50s	remaining: 1m 58s
# 353:	learn: 0.1597356	total: 2m 50s	remaining: 1m 58s
# 354:	learn: 0.1597315	total: 2m 50s	remaining: 1m 57s
# 355:	learn: 0.1597302	total: 2m 51s	remaining: 1m 57s
# 356:	learn: 0.1597287	total: 2m 51s	remaining: 1m 56s
# 357:	learn: 0.1597192	total: 2m 52s	remaining: 1m 56s
# 358:	learn: 0.1597164	total: 2m 52s	remaining: 1m 55s
# 359:	learn: 0.1597157	total: 2m 52s	remaining: 1m 55s
# 360:	learn: 0.1597048	total: 2m 53s	remaining: 1m 54s
# 361:	learn: 0.1597039	total: 2m 53s	remaining: 1m 54s
# 362:	learn: 0.1596985	total: 2m 54s	remaining: 1m 53s
# 363:	learn: 0.1596959	total: 2m 54s	remaining: 1m 53s
# 364:	learn: 0.1596915	total: 2m 54s	remaining: 1m 52s
# 365:	learn: 0.1596827	total: 2m 55s	remaining: 1m 52s
# 366:	learn: 0.1596800	total: 2m 55s	remaining: 1m 51s
# 367:	learn: 0.1596796	total: 2m 55s	remaining: 1m 50s
# 368:	learn: 0.1596777	total: 2m 56s	remaining: 1m 50s
# 369:	learn: 0.1596765	total: 2m 56s	remaining: 1m 49s
# 370:	learn: 0.1596752	total: 2m 57s	remaining: 1m 49s
# 371:	learn: 0.1596740	total: 2m 57s	remaining: 1m 48s
# 372:	learn: 0.1596698	total: 2m 58s	remaining: 1m 48s
# 373:	learn: 0.1596692	total: 2m 58s	remaining: 1m 47s
# 374:	learn: 0.1596673	total: 2m 58s	remaining: 1m 47s
# 375:	learn: 0.1596664	total: 2m 59s	remaining: 1m 46s
# 376:	learn: 0.1596620	total: 2m 59s	remaining: 1m 46s
# 377:	learn: 0.1596582	total: 3m	remaining: 1m 45s
# 378:	learn: 0.1596577	total: 3m	remaining: 1m 45s
# 379:	learn: 0.1596547	total: 3m	remaining: 1m 44s
# 380:	learn: 0.1596465	total: 3m 1s	remaining: 1m 44s
# 381:	learn: 0.1596375	total: 3m 1s	remaining: 1m 43s
# 382:	learn: 0.1596357	total: 3m 2s	remaining: 1m 43s
# 383:	learn: 0.1596331	total: 3m 2s	remaining: 1m 42s
# 384:	learn: 0.1596279	total: 3m 3s	remaining: 1m 42s
# 385:	learn: 0.1596264	total: 3m 3s	remaining: 1m 41s
# 386:	learn: 0.1596216	total: 3m 3s	remaining: 1m 41s
# 387:	learn: 0.1596168	total: 3m 4s	remaining: 1m 40s
# 388:	learn: 0.1596116	total: 3m 4s	remaining: 1m 40s
# 389:	learn: 0.1596079	total: 3m 4s	remaining: 1m 39s
# 390:	learn: 0.1596044	total: 3m 5s	remaining: 1m 39s
# 391:	learn: 0.1596025	total: 3m 5s	remaining: 1m 38s
# 392:	learn: 0.1596004	total: 3m 6s	remaining: 1m 38s
# 393:	learn: 0.1595954	total: 3m 6s	remaining: 1m 37s
# 394:	learn: 0.1595924	total: 3m 6s	remaining: 1m 37s
# 395:	learn: 0.1595830	total: 3m 7s	remaining: 1m 36s
# 396:	learn: 0.1595773	total: 3m 7s	remaining: 1m 36s
# 397:	learn: 0.1595756	total: 3m 8s	remaining: 1m 35s
# 398:	learn: 0.1595679	total: 3m 8s	remaining: 1m 34s
# 399:	learn: 0.1595666	total: 3m 8s	remaining: 1m 34s
# 400:	learn: 0.1595591	total: 3m 9s	remaining: 1m 33s
# 401:	learn: 0.1595573	total: 3m 9s	remaining: 1m 33s
# 402:	learn: 0.1595507	total: 3m 10s	remaining: 1m 32s

# %%
grid_result.grid_scores_
# Out:
# /Users/apple/venv/lib/python3.6/site-packages/sklearn/model_selection/_search.py:761: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# [mean: -0.06907, std: 0.00183, params: {'colsample_bytree': 0.8, 'learning_rate': 0.03, 'max_depth': -1, 'min_child_samples': 100, 'min_child_weight': 0.001, 'min_split_gain': 0, 'n_eatimators': 512, 'num_leaves': 140, 'ramdon_state': 21, 'reg_alpha': 0.01, 'reg_lambda': 100, 'subsample': 0.8, 'subsample_for_bin': 50000, 'subsample_freq': 1}]

# %% [markdown]
# ### Learning Curve

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.learning_curve import learning_curve
# Out:
# /Users/apple/venv/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/apple/venv/lib/python3.6/site-packages/sklearn/learning_curve.py:22: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)

# %%
def plot_learning_curve(estimator, X, y, ylim=None, cv=None, train_sizes=np.linspace(.05, 1., 20), verbose=0, plot=True):
    
    train_sizes, train_scores, test_scores = learning_curve(
            estimator, X, y, cv=cv, train_sizes=train_sizes, scoring = 'neg_mean_absolute_error',verbose=verbose)

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)

    if plot:
        plt.figure()
        if ylim is not None:
            plt.ylim(*ylim)
        plt.xlabel(u"number of samples")
        plt.ylabel(u"score")
        plt.gca().invert_yaxis()
        plt.grid()
        plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, 
                         alpha=0.1, color="b")
        plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, 
                         alpha=0.1, color="r")
        plt.plot(train_sizes, train_scores_mean, 'o-', color="b", label=u"training set score")
        plt.plot(train_sizes, test_scores_mean, 'o-', color="r", label=u"validation set score")

        plt.legend(loc="best")

        plt.draw()
        plt.show()
        plt.gca().invert_yaxis()

    midpoint = ((train_scores_mean[-1] + train_scores_std[-1]) + (test_scores_mean[-1] - test_scores_std[-1])) / 2
    diff = (train_scores_mean[-1] + train_scores_std[-1]) - (test_scores_mean[-1] - test_scores_std[-1])
    return midpoint, diff

# %%
bst = lgb.LGBMRegressor(n_jobs = -1, random_state = 42,silent = False,
                            learning_rate = 0.014,
                            n_estimators = 512,
                            num_leaves = 140,
                            reg_alpha = 0.01,
                            reg_lambda = 100,
                            min_split_gain = 0,
                            min_child_samples = 100,
                            subsample = 0.8,
                            subsample_for_bin = 50000,
                            colsample_bytree = 0.8,
                            subsample_freq = 1,
                            max_depth = -1,
                            min_child_weight = 0.001
                        
                           )
start = time.time()
_,_ = plot_learning_curve(bst, new_X_train, y_train)
during_time = time.time() - start
print(during_time)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-8f4c53cda7ca> in <module>()
#      15
#      16                            )
# ---> 17 _,_ = plot_learning_curve(bst, new_X_train, y_train)
#
# <ipython-input-50-469a51b5c56a> in plot_learning_curve(estimator, X, y, ylim, cv, train_sizes, verbose, plot)
#       2
#       3     train_sizes, train_scores, test_scores = learning_curve(
# ----> 4             estimator, X, y, cv=cv, train_sizes=train_sizes, scoring = 'neg_mean_absolute_error',verbose=verbose)
#       5
#       6     train_scores_mean = np.mean(train_scores, axis=1)
#
# ~/venv/lib/python3.6/site-packages/sklearn/learning_curve.py in learning_curve(estimator, X, y, train_sizes, cv, scoring, exploit_incremental_learning, n_jobs, pre_dispatch, verbose, error_score)
#     169             verbose, parameters=None, fit_params=None, return_train_score=True,
#     170             error_score=error_score)
# --> 171             for train, test in cv for n_train_samples in train_sizes_abs)
#     172         out = np.array(out)[:, :2]
#     173         n_cv_folds = out.shape[0] // n_unique_ticks
#
# ~/venv/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# ~/venv/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# ~/venv/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# ~/venv/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# ~/venv/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# ~/venv/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/venv/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/venv/lib/python3.6/site-packages/sklearn/cross_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, error_score)
#    1673             estimator.fit(X_train, **fit_params)
#    1674         else:
# -> 1675             estimator.fit(X_train, y_train, **fit_params)
#    1676
#    1677     except Exception as e:
#
# ~/venv/lib/python3.6/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     632                                        verbose=verbose, feature_name=feature_name,
#     633                                        categorical_feature=categorical_feature,
# --> 634                                        callbacks=callbacks)
#     635         return self
#     636
#
# ~/venv/lib/python3.6/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     472                               verbose_eval=verbose, feature_name=feature_name,
#     473                               categorical_feature=categorical_feature,
# --> 474                               callbacks=callbacks)
#     475
#     476         if evals_result:
#
# ~/venv/lib/python3.6/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     202                                     evaluation_result_list=None))
#     203
# --> 204         booster.update(fobj=fobj)
#     205
#     206         evaluation_result_list = []
#
# ~/venv/lib/python3.6/site-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    1526             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1527                 self.handle,
# -> 1528                 ctypes.byref(is_finished)))
#    1529             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1530             return is_finished.value == 1
#
# KeyboardInterrupt:

# %% [markdown]
# ### Testing

# %%
# read in test
test_data2016 = pd.read_csv(test_datapath_2016, index_col=0)
test_data2017 = pd.read_csv(test_datapath_2017, index_col=0)

print("[2016] num of instances: ", test_data2016.shape[0])
print("[2017] num of instances: ", test_data2017.shape[0])

# save parcelid for merge 
test_parcelid16 = test_data2016['parcelid']
test_parcelid17 = test_data2017['parcelid']

# drop parcelid col
test_data2016 = test_data2016.drop('parcelid', axis=1)
test_data2017 = test_data2017.drop('parcelid', axis=1)

# generate transaction date
test_year = np.repeat(2016, test_data2016.shape[0])
test_quarter = np.repeat(4, test_data2016.shape[0])

test_month10_16 = np.repeat(10, test_data2016.shape[0])
test_month11_16 = np.repeat(11, test_data2016.shape[0])
test_month12_16 = np.repeat(12, test_data2016.shape[0])

test_month10_17 = np.repeat(22, test_data2017.shape[0])
test_month11_17 = np.repeat(23, test_data2017.shape[0])
test_month12_17 = np.repeat(24, test_data2017.shape[0])

# get new test data with transaction date
X_test10_16 = gen_testdata(test_data2016, test_year, test_month10_16,test_quarter)
X_test11_16 = gen_testdata(test_data2016, test_year, test_month11_16,test_quarter)
X_test12_16 = gen_testdata(test_data2016, test_year, test_month12_16,test_quarter)

X_test10_17 = gen_testdata(test_data2017, test_year, test_month10_17,test_quarter)
X_test11_17 = gen_testdata(test_data2017, test_year, test_month11_17,test_quarter)
X_test12_17 = gen_testdata(test_data2017, test_year, test_month12_17,test_quarter)
# Out:
# /Users/apple/venv/lib/python3.6/site-packages/numpy/lib/arraysetops.py:472: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# [2016] num of instances:  2985217
# [2017] num of instances:  2985217

# %%
X_test10_16 = X_test10_16[train_feature]
X_test11_16 = X_test11_16[train_feature]
X_test12_16 = X_test12_16[train_feature]
X_test10_17 = X_test10_17[train_feature]
X_test11_17 = X_test11_17[train_feature]
X_test12_17 = X_test12_17[train_feature]

# %%
def train_and_test(X_train,y_train,X_test):
    start = time.time()
    bst = lgb.LGBMRegressor(n_jobs = -1, random_state = 42,silent = False,
                            learning_rate = 0.014,
                            n_estimators = 512,
                            num_leaves = 140,
                            reg_alpha = 0.01,
                            reg_lambda = 100,
                            min_split_gain = 0,
                            min_child_samples = 100,
                            subsample = 0.8,
                            subsample_for_bin = 50000,
                            colsample_bytree = 0.8,
                            subsample_freq = 1,
                            max_depth  = -1,
                            min_child_weight = 0.001
                           )
    bst.fit(X_train, y_train)
    y_pred = bst.predict(X_test)
    print('time using:%.2f'%(time.time()-start))
    
    return y_pred

# %%
y_pred10_16 = train_and_test(new_X_train, y_train, X_test10_16.values)
y_pred11_16 = train_and_test(new_X_train, y_train, X_test11_16.values)
y_pred12_16 = train_and_test(new_X_train, y_train, X_test12_16.values)
y_pred10_17 = train_and_test(new_X_train, y_train, X_test10_17.values)
y_pred11_17 = train_and_test(new_X_train, y_train, X_test11_17.values)
y_pred12_17 = train_and_test(new_X_train, y_train, X_test12_17.values)
# Out:
# time using:222.55
# time using:196.50
# time using:217.11
# time using:168.77
# time using:187.18
# time using:185.88

# %%
# merged on Parcelid for predicted result on test data

test_dict_16 = {'Parcelid': test_parcelid16, '201610': y_pred10_16, '201611': y_pred11_16, '201612': y_pred12_16}
test_dict_17 = {'Parcelid': test_parcelid17, '201710': y_pred10_17, '201711': y_pred11_17, '201712': y_pred12_17}

df_test_16 = pd.DataFrame(data=test_dict_16)
df_test_17 = pd.DataFrame(data=test_dict_17)

df_merged = df_test_16.merge(df_test_17, left_on='Parcelid', right_on='Parcelid', how='outer')
print(df_merged)

# handle submission file
submitfile = "./zillow data/sample_submission.csv"

submit_df = pd.read_csv(submitfile)
print(submit_df.shape[0], submit_df.shape[1])

assert(submit_df.shape[0] == df_merged.shape[0]), "Error: invalid row size for submit!"
df_merged.to_csv("./zillow data/new_submission1.csv", index=False)
# Out:
#           Parcelid    201610    201611    201612    201710    201711    201712
# 0         10754147  0.028049  0.028431  0.029355  0.049639  0.049639  0.049639
# 1         10759547 -0.004185 -0.003239 -0.001811  0.013211  0.013211  0.013211
# 2         10843547  0.049635  0.049635  0.049635  0.103998  0.103998  0.103998
# 3         10859147  0.092716  0.091380  0.091508  0.127437  0.127437  0.127437
# 4         10879947  0.027588  0.027588  0.028027  0.054558  0.054558  0.054558
# 5         10898347  0.032808  0.032840  0.032611  0.048364  0.048364  0.048364
# 6         10933547 -0.012797 -0.013247 -0.013965  0.025217  0.025217  0.025217
# 7         10940747  0.038732  0.038614  0.040091  0.058608  0.058608  0.058608
# 8         10954547  0.043967  0.044350  0.045274  0.064318  0.064318  0.064318
# 9         10976347 -0.000247 -0.000357  0.001120  0.029871  0.029871  0.029871
# 10        11073947  0.003286  0.003830  0.004527  0.025780  0.025780  0.025780
# 11        11114347  0.018199  0.018010  0.018200  0.037514  0.037514  0.037514
# 12        11116947 -0.015289 -0.013641 -0.013452  0.005903  0.005903  0.005903
# 13        11142747 -0.009960 -0.009585 -0.008661  0.029054  0.029054  0.029054
# 14        11193347  0.002202  0.002014  0.002938  0.030589  0.030589  0.030589
# 15        11215747  0.005914  0.006289  0.007213  0.037064  0.037064  0.037064
# 16        11229347  0.064072  0.064072  0.064575  0.076461  0.076461  0.076461
# 17        11287347  0.015328  0.015832  0.018130  0.048105  0.048105  0.048105
# 18        11288547  0.050706  0.049995  0.050178  0.089920  0.089920  0.089920
# 19        11324547  0.005925  0.005851  0.006118  0.032029  0.032029  0.032029
# 20        11391347  0.084935  0.084584  0.083839  0.081892  0.081892  0.081892
# 21        11395747  0.065134  0.064104  0.063260  0.065419  0.065419  0.065419
# 22        11404347 -0.004418 -0.005607 -0.005728  0.007097  0.007097  0.007097
# 23        11405747  0.006858  0.007254  0.008226  0.038043  0.038043  0.038043
# 24        11417147 -0.022726 -0.021941 -0.018429  0.032012  0.032012  0.032012
# 25        11457547 -0.049805 -0.047267 -0.045968 -0.024125 -0.024125 -0.024125
# 26        11488147 -0.004852 -0.004739 -0.005445  0.018051  0.018051  0.018051
# 27        11520747  0.055412  0.055870  0.055100  0.101228  0.101228  0.101228
# 28        11524947  0.009432  0.009781  0.009929  0.010371  0.010371  0.010371
# 29        11544747  0.014527  0.014041  0.013701  0.026668  0.026668  0.026668
# ...            ...       ...       ...       ...       ...       ...       ...
# 2985187  167636430 -0.107497 -0.106404 -0.106675  0.007425  0.007425  0.007425
# 2985188  167690630 -0.107497 -0.106404 -0.106675  0.017522  0.017522  0.017522
# 2985189  167636630 -0.107497 -0.106404 -0.106675  0.018751  0.018751  0.018751
# 2985190   10834030 -0.107497 -0.106404 -0.106675  0.038850  0.038850  0.038850
# 2985191  167637430 -0.107497 -0.106404 -0.106675  0.044426  0.044426  0.044426
# 2985192  167637630 -0.107497 -0.106404 -0.106675  0.235611  0.235611  0.235611
# 2985193  167637230 -0.107497 -0.106404 -0.106675  0.032963  0.032963  0.032963
# 2985194   11645030 -0.107497 -0.106404 -0.106675  0.015367  0.015367  0.015367
# 2985195  167689030 -0.107497 -0.106404 -0.106675  0.035714  0.035714  0.035714
# 2985196  167638630 -0.107497 -0.106404 -0.106675  0.020956  0.020956  0.020956
# 2985197  167638430 -0.107497 -0.106404 -0.106675  0.030188  0.030188  0.030188
# 2985198   14342030 -0.107497 -0.106404 -0.106675  0.157966  0.157966  0.157966
# 2985199  167638230 -0.107497 -0.106404 -0.106675  0.069180  0.069180  0.069180
# 2985200  167637830 -0.107497 -0.106404 -0.106675  0.040485  0.040485  0.040485
# 2985201  167639230 -0.107497 -0.106404 -0.106675  0.033996  0.033996  0.033996
# 2985202   14341030 -0.107497 -0.106404 -0.106675  0.104267  0.104267  0.104267
# 2985203   14341630 -0.107497 -0.106404 -0.106675  0.123310  0.123310  0.123310
# 2985204   14367630 -0.107497 -0.106404 -0.106675  0.047818  0.047818  0.047818
# 2985205  167638830 -0.107497 -0.106404 -0.106675  0.012361  0.012361  0.012361
# 2985206   12572230 -0.107497 -0.106404 -0.106675  0.028810  0.028810  0.028810
# 2985207   14460030 -0.107497 -0.106404 -0.106675  0.018409  0.018409  0.018409
# 2985208   14284830 -0.107497 -0.106404 -0.106675  0.082278  0.082278  0.082278
# 2985209   14285230 -0.107497 -0.106404 -0.106675  0.104172  0.104172  0.104172
# 2985210   14455630 -0.107497 -0.106404 -0.106675  0.120609  0.120609  0.120609
# 2985211   11117630 -0.107497 -0.106404 -0.106675  0.025976  0.025976  0.025976
# 2985212  168176230 -0.107497 -0.106404 -0.106675  0.130852  0.130852  0.130852
# 2985213   14273630 -0.107497 -0.106404 -0.106675  0.046544  0.046544  0.046544
# 2985214  168040630 -0.107497 -0.106404 -0.106675  0.041310  0.041310  0.041310
# 2985215  168040830 -0.107497 -0.106404 -0.106675  0.088904  0.088904  0.088904
# 2985216  168040430 -0.107497 -0.106404 -0.106675  0.050423  0.050423  0.050423
#
# [2985217 rows x 7 columns]
# 2985217 7

# %%
df_merged.to_csv("./zillow data/new_draft_submission1.csv", index=False)
