# %%
import pandas as pd
import missingValue as missV

# %%
train_data_2016 = pd.read_csv('./zillow data/train_2016_v2.csv')
train_data_2017 = pd.read_csv('./zillow data/train_2017.csv')
properties_2017 = pd.read_csv('./zillow data/properties_2017.csv')
properties_2016 = pd.read_csv('./zillow data/properties_2016.csv')
# Out:
# /Users/apple/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/apple/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
missV.print_missing(properties_2017)
# Out:
# Each feature missing value:
# parcelid                              0
# fips                               2932
# propertylandusetypeid              2932
# rawcensustractandblock             2932
# regionidcounty                     2932
# longitude                          2932
# latitude                           2932
# assessmentyear                     2933
# bedroomcnt                         2945
# bathroomcnt                        2957
# roomcnt                            2969
# propertycountylandusecode          2999
# regionidzip                       12714
# taxamount                         22752
# taxvaluedollarcnt                 34266
# calculatedfinishedsquarefeet      45097
# structuretaxvaluedollarcnt        46464
# yearbuilt                         47833
# landtaxvaluedollarcnt             59926
# regionidcity                      62128
# censustractandblock               74985
# fullbathcnt                      117156
# calculatedbathnbr                117156
# ...

# %%
properties_2017.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  5.0                    NaN
# 3          0.0         0.0                  3.0                    6.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid         ...           numberofstories  \
# ...

# %%
for ele in properties_2017.columns.values:
    print(properties_2017[ele].unique())
# Out:
# [10754147 10759547 10843547 ... 17203030 14242830 12766630]
# [nan  1. 13.  9.  5. 11. 12.  3.]
# [nan  7. 21.  8.  2.  3.  5. 10. 27.]
# [  nan  216.  555.  224.  782.  651.  516.  600.  732. 1145.  220.  420.
#   688.  144.  540. 1312.  690.  640.  550.   63.  198. 1120.  924. 1572.
#  1035.  195.  544.  498.  176.  360.  154.  240.  616. 1131.  200. 1016.
#  1089. 2443.  276.  396.  149.  168.  495.  208.  560.  939.  704.  460.
#  1152.  462. 1904.  888.  170.  625.  450.   72.  252.  637.   96. 1172.
#  1464.  787.  501.  473.  318.  112.  394.  985.  169.  400.  826.  780.
#  1350.  610. 1528.  255.  164.  315.  836.  630.  160. 1508.  775.  676.
#   448.  756.  912.  179.  700.  348.  595.  231.  100.  266.  620.  757.
#   786.  872.  672.  831. 1544.  946.  180.  313.  314.  440.  528.   36.
#   320.  515.  196.  119. 3374.  606.  736.  678. 1282.  135.   64.  506.
#   414. 1296. 1197. 1112.  814.  530.  165. 1314.  352.  282.  293.  805.
# ...

# %%
missV.print_missing(properties_2016)
# Out:
# Each feature missing value:
# parcelid                              0
# fips                              11437
# propertylandusetypeid             11437
# rawcensustractandblock            11437
# regionidcounty                    11437
# longitude                         11437
# latitude                          11437
# assessmentyear                    11439
# bedroomcnt                        11450
# bathroomcnt                       11462
# roomcnt                           11475
# propertycountylandusecode         12277
# regionidzip                       13980
# taxamount                         31250
# taxvaluedollarcnt                 42550
# structuretaxvaluedollarcnt        54982
# calculatedfinishedsquarefeet      55565
# yearbuilt                         59928
# regionidcity                      62845
# landtaxvaluedollarcnt             67733
# censustractandblock               75126
# fullbathcnt                      128912
# calculatedbathnbr                128912
# ...

# %%
properties_2016.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid         ...           numberofstories  \
# ...

# %%
properties_2016.describe()
# Out:
#            parcelid  airconditioningtypeid  architecturalstyletypeid  \
# count  2.985217e+06          811519.000000               6061.000000
# mean   1.332586e+07               1.931166                  7.202607
# std    7.909966e+06               3.148587                  2.436290
# min    1.071172e+07               1.000000                  2.000000
# 25%    1.164371e+07               1.000000                  7.000000
# 50%    1.254509e+07               1.000000                  7.000000
# 75%    1.409712e+07               1.000000                  7.000000
# max    1.696019e+08              13.000000                 27.000000
#
#        basementsqft   bathroomcnt    bedroomcnt  buildingclasstypeid  \
# count   1628.000000  2.973755e+06  2.973767e+06         12629.000000
# mean     646.883292  2.209143e+00  3.088949e+00             3.725948
# std      538.793473  1.077754e+00  1.275859e+00             0.501700
# ...

# %%
properties_2017.describe()
# Out:
#            parcelid  airconditioningtypeid  architecturalstyletypeid  \
# count  2.985217e+06          815362.000000               6061.000000
# mean   1.332586e+07               1.945723                  7.202607
# std    7.909966e+06               3.160507                  2.436290
# min    1.071172e+07               1.000000                  2.000000
# 25%    1.164371e+07               1.000000                  7.000000
# 50%    1.254509e+07               1.000000                  7.000000
# 75%    1.409712e+07               1.000000                  7.000000
# max    1.696019e+08              13.000000                 27.000000
#
#        basementsqft   bathroomcnt    bedroomcnt  buildingclasstypeid  \
# count   1627.000000  2.982260e+06  2.982272e+06         12731.000000
# mean     647.220652  2.216196e+00  3.093362e+00             3.734742
# std      538.787104  1.078250e+00  1.271569e+00             0.500371
# ...

# %%
properties_2016.columns
# Out:
# Index(['parcelid', 'airconditioningtypeid', 'architecturalstyletypeid',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingclasstypeid',
#        'buildingqualitytypeid', 'calculatedbathnbr', 'decktypeid',
#        'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'finishedsquarefeet13', 'finishedsquarefeet15',
#        'finishedsquarefeet50', 'finishedsquarefeet6', 'fips', 'fireplacecnt',
#        'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'hashottuborspa',
#        'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet',
#        'poolcnt', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
#        'propertycountylandusecode', 'propertylandusetypeid',
#        'propertyzoningdesc', 'rawcensustractandblock', 'regionidcity',
#        'regionidcounty', 'regionidneighborhood', 'regionidzip', 'roomcnt',
#        'storytypeid', 'threequarterbathnbr', 'typeconstructiontypeid',
# ...

# %%
class_feature = ['airconditioningtypeid', 'architecturalstyletypeid','buildingclasstypeid','buildingqualitytypeid',
                'decktypeid','fips','hashottuborspa','heatingorsystemtypeid','pooltypeid10', 'pooltypeid2', 'pooltypeid7',
                'propertycountylandusecode','propertylandusetypeid','propertyzoningdesc','rawcensustractandblock',
                'regionidcity','regionidcounty', 'regionidneighborhood', 'regionidzip','storytypeid','typeconstructiontypeid',
                'fireplaceflag','taxdelinquencyflag','taxdelinquencyyear','censustractandblock']

quantity_feature = ['basementsqft','finishedfloor1squarefeet',
                    'calculatedfinishedsquarefeet','finishedsquarefeet12', 'finishedsquarefeet13', 
                    'finishedsquarefeet15','finishedsquarefeet50', 'finishedsquarefeet6', 
                    'garagetotalsqft','latitude', 'longitude','lotsizesquarefeet', 'poolsizesum',
                    'yardbuildingsqft17', 'yardbuildingsqft26','structuretaxvaluedollarcnt',
                    'taxvaluedollarcnt', 'landtaxvaluedollarcnt','taxamount']

integer_feature = ['bathroomcnt', 'bedroomcnt','calculatedbathnbr','fireplacecnt','numberofstories','fullbathcnt',
                   'garagecarcnt','poolcnt','unitcnt','roomcnt', 'threequarterbathnbr','yearbuilt',
                   'assessmentyear']

string_feature= ['hashottuborspa','propertycountylandusecode','propertyzoningdesc','taxdelinquencyflag', 'fireplaceflag']

# %%
len(integer_feature) + len(quantity_feature) + len(class_feature)
# Out:
# 57

# %%
def label_encode_features(data, features, show_info = False):
    df = data.loc[:,features]
    print('encoding labels ....')
    for index1,ele in enumerate(features):
        p = data.loc[:,ele]
        p = p.sort_values(ascending = True)
        size_mapping = dict()
        for index2, element in enumerate(p.unique()):
            size_mapping[element] = index2
        p = p.map(size_mapping)
        if show_info == True:
            print(ele)
        p = p.replace(len(p.unique())-1,np.nan)
        df.loc[:,ele] = p
    print('merging results ..... ')
    for ele in features:
        if show_info == True:
            print(ele)
        data[ele] = df.loc[:,ele]
    print('successfully done.....')
    return data

# %%
def fill_with_mean(data, features, show_info = False):
    df = data.loc[:,features]
    print('begin filling...')
    for ele in features:
        if show_info == True:
            print(ele)
        p = df.loc[:,ele]
        p[p.isna()] = p[p.notna()].mean()
        df[ele] = p
    print('finished! merge result...')
    for ele in features:
        if show_info == True:
            print(ele)
        data[ele] = df.loc[:,ele]
    print('successflly done!')
    return data

# %%
def fill_with_mode(data, features, show_info = False):
    df = data.loc[:,features]
    print('begin filling...')
    for ele in features:
        if show_info == True:
            print(ele)
        p = df.loc[:,ele]
        p[p.isna()] = p[p.notna()].mode()[0]
        df[ele] = p
    print('finished! merge result...')
    for ele in features:
        if show_info == True:
            print(ele)
        data[ele] = df.loc[:,ele]
    print('successflly done!')
    return data

# %%
def fill_with_int_mean(data, features, show_info = False):
    df = data.loc[:,features]
    print('begin filling...')
    for ele in features:
        if show_info == True:
            print(ele)
        p = df.loc[:,ele]
        p[p.isna()] = int(p[p.notna()].mean())
        df[ele] = p
    print('finished! merge result...')
    for ele in features:
        if show_info == True:
            print(ele)
        data[ele] = df.loc[:,ele]
    print('successflly done!')
    return data

# %%
properties_2016 = label_encode_features(properties_2016,string_feature,show_info = False)
properties_2017 = label_encode_features(properties_2017,string_feature,show_info = False)
# Out:
# encoding labels ....
# merging results .....
# successfully done.....
# encoding labels ....
# merging results .....
# successfully done.....

# %%
properties_2016 = fill_with_mode(properties_2016,class_feature,show_info = True)
properties_2017 = fill_with_mode(properties_2017,class_feature,show_info = True)
# Out:
# begin filling...
# airconditioningtypeid
# architecturalstyletypeid
# buildingclasstypeid
# buildingqualitytypeid
# decktypeid
# fips
# hashottuborspa
# heatingorsystemtypeid
# pooltypeid10
# pooltypeid2
# pooltypeid7
# propertycountylandusecode
# propertylandusetypeid
# propertyzoningdesc
# rawcensustractandblock
# regionidcity
# regionidcounty
# regionidneighborhood
# regionidzip
# storytypeid
# typeconstructiontypeid
# fireplaceflag
# taxdelinquencyflag
# taxdelinquencyyear
# censustractandblock
# finished! merge result...
# airconditioningtypeid
# architecturalstyletypeid
# buildingclasstypeid
# buildingqualitytypeid
# decktypeid
# fips
# hashottuborspa
# heatingorsystemtypeid
# pooltypeid10
# pooltypeid2
# pooltypeid7
# propertycountylandusecode
# propertylandusetypeid
# propertyzoningdesc
# rawcensustractandblock
# regionidcity
# regionidcounty
# regionidneighborhood
# regionidzip
# storytypeid
# typeconstructiontypeid
# fireplaceflag
# taxdelinquencyflag
# taxdelinquencyyear
# ...

# %%
properties_2016 = fill_with_mean(properties_2016,quantity_feature,show_info = True)
properties_2017 = fill_with_mean(properties_2017,quantity_feature,show_info = True)
# Out:
# begin filling...
# basementsqft
# finishedfloor1squarefeet
# calculatedfinishedsquarefeet
# finishedsquarefeet12
# finishedsquarefeet13
# finishedsquarefeet15
# finishedsquarefeet50
# finishedsquarefeet6
# garagetotalsqft
# latitude
# longitude
# lotsizesquarefeet
# poolsizesum
# yardbuildingsqft17
# yardbuildingsqft26
# structuretaxvaluedollarcnt
# taxvaluedollarcnt
# landtaxvaluedollarcnt
# taxamount
# finished! merge result...
# basementsqft
# finishedfloor1squarefeet
# calculatedfinishedsquarefeet
# finishedsquarefeet12
# finishedsquarefeet13
# finishedsquarefeet15
# finishedsquarefeet50
# finishedsquarefeet6
# garagetotalsqft
# latitude
# longitude
# lotsizesquarefeet
# poolsizesum
# yardbuildingsqft17
# yardbuildingsqft26
# structuretaxvaluedollarcnt
# taxvaluedollarcnt
# landtaxvaluedollarcnt
# taxamount
# successflly done!
# begin filling...
# basementsqft
# finishedfloor1squarefeet
# calculatedfinishedsquarefeet
# finishedsquarefeet12
# finishedsquarefeet13
# ...

# %%
properties_2016 = fill_with_int_mean(properties_2016,integer_feature,show_info = True)
properties_2017 = fill_with_int_mean(properties_2017,integer_feature,show_info = True)
# Out:
# begin filling...
# bathroomcnt
# bedroomcnt
# calculatedbathnbr
# fireplacecnt
# numberofstories
# fullbathcnt
# garagecarcnt
# poolcnt
# unitcnt
# roomcnt
# threequarterbathnbr
# yearbuilt
# assessmentyear
# finished! merge result...
# bathroomcnt
# bedroomcnt
# calculatedbathnbr
# fireplacecnt
# numberofstories
# fullbathcnt
# garagecarcnt
# poolcnt
# unitcnt
# roomcnt
# threequarterbathnbr
# yearbuilt
# assessmentyear
# successflly done!
# begin filling...
# bathroomcnt
# bedroomcnt
# calculatedbathnbr
# fireplacecnt
# numberofstories
# fullbathcnt
# garagecarcnt
# poolcnt
# unitcnt
# roomcnt
# threequarterbathnbr
# yearbuilt
# assessmentyear
# finished! merge result...
# bathroomcnt
# bedroomcnt
# calculatedbathnbr
# fireplacecnt
# numberofstories
# fullbathcnt
# garagecarcnt
# poolcnt
# unitcnt
# roomcnt
# threequarterbathnbr
# yearbuilt
# assessmentyear
# successflly done!

# %%
p = properties_2016['garagecarcnt']
p[p.isna()] = int(p[p.notna()].mean())
# Out:
# /Users/apple/venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
missV.print_missing(properties_2016)
# Out:
# Each feature missing value:
# parcelid                        0
# pooltypeid7                     0
# propertycountylandusecode       0
# propertylandusetypeid           0
# propertyzoningdesc              0
# rawcensustractandblock          0
# regionidcity                    0
# regionidcounty                  0
# regionidneighborhood            0
# regionidzip                     0
# roomcnt                         0
# storytypeid                     0
# threequarterbathnbr             0
# typeconstructiontypeid          0
# unitcnt                         0
# yardbuildingsqft17              0
# yardbuildingsqft26              0
# yearbuilt                       0
# numberofstories                 0
# fireplaceflag                   0
# structuretaxvaluedollarcnt      0
# taxvaluedollarcnt               0
# assessmentyear                  0
# landtaxvaluedollarcnt           0
# taxamount                       0
# taxdelinquencyflag              0
# ...

# %%
merged_2017 = pd.merge(train_data_2017,properties_2017,on="parcelid",how="left")
merged_2017
# Out:
#        parcelid  logerror transactiondate  airconditioningtypeid  \
# 0      14297519  0.025595      2017-01-01                    1.0
# 1      17052889  0.055619      2017-01-01                    1.0
# 2      14186244  0.005383      2017-01-01                    1.0
# 3      12177905 -0.103410      2017-01-01                    1.0
# 4      10887214  0.006940      2017-01-01                    1.0
# 5      17143294 -0.020526      2017-01-01                    1.0
# 6      12095076 -0.001011      2017-01-01                    1.0
# 7      12069064  0.101723      2017-01-01                    1.0
# 8      12790562 -0.040966      2017-01-02                    1.0
# 9      11542646 -0.036763      2017-01-02                    1.0
# 10     11104527  0.005963      2017-01-02                    1.0
# 11     13984101 -0.147997      2017-01-02                    1.0
# 12     14705431 -0.028835      2017-01-02                    1.0
# ...

# %%
merged_2016 = pd.merge(train_data_2016,properties_2016,on="parcelid",how="left")
merged_2016
# Out:
#        parcelid  logerror transactiondate  airconditioningtypeid  \
# 0      11016594    0.0276      2016-01-01                    1.0
# 1      14366692   -0.1684      2016-01-01                    1.0
# 2      12098116   -0.0040      2016-01-01                    1.0
# 3      12643413    0.0218      2016-01-02                    1.0
# 4      14432541   -0.0050      2016-01-02                    1.0
# 5      11509835   -0.2705      2016-01-02                    1.0
# 6      12286022    0.0440      2016-01-02                    1.0
# 7      17177301    0.1638      2016-01-02                    1.0
# 8      14739064   -0.0030      2016-01-02                    1.0
# 9      14677559    0.0843      2016-01-03                    1.0
# 10     10854446    0.3825      2016-01-03                    1.0
# 11     11672170   -0.0161      2016-01-03                    1.0
# 12     10949761    0.0344      2016-01-03                    1.0
# ...

# %%
merged_2017.to_csv('./zillow data/merged_2017 v2.csv')
properties_2017.to_csv('./zillow data/properties_2017 v2.csv')

# %%
merged_2016.to_csv('./zillow data/merged_2016 v2.csv')
properties_2016.to_csv('./zillow data/properties_2016 v2.csv')
