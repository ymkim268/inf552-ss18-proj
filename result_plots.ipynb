# %%
import numpy as np
import matplotlib.pyplot as plt

cols1 = ["42 Features", "Model", "Parameters", 
        "\'16 Train", "\'16 Test", "Parameters",
       "\'17 Train", "\'17 Test"]

data1 = [["Baseline", "Linear Regr(OLS)", "None", 0.068425, 0.0652034, "None", 0.070904, 0.0765418],
        ["Model 1", "Lasso", "0.00001", 0.068305, 0.0650139, "0.00002", 0.070681, 0.0762138],
        ["Model 2", "ElasticNet", "0.00001, 0.9", 0.068322, 0.0650566, "0.00002, 0.9", 0.070675, 0.0762156],
        ["Model 3", "Ridge", "1.00", 0.068308, 0.0649356, "1.00", 0.070545, 0.0760404],
        ["Model 4", "Ransac + Lasso", "0.8, 10", 0.068007, 0.0648844, "0.8, 10", 0.070006, 0.0758022],
        ["Model 5", "Ransac + Ridge", "0.3, 100", 0.068001, 0.0650341, "0.3, 50", 0.069786, 0.0757591]]

the_table = plt.table(cellText=data1,
                      colLabels=cols1, loc="left")

the_table.set_fontsize(42)
the_table.scale(4, 4)
plt.axis('tight')
plt.axis('off')

plt.show()

# %%
x = ["Baseline", "Model 1", "Model 2", "Model 3", "Model 4", "Model 5"]

np_data1 = np.array(data1)
x_label = np_data1[:,0]

y_train16 = np_data1[:,3]
y_test16 = np_data1[:,4]

y_train17 = np_data1[:,6]
y_test17 = np_data1[:,7]

fig1 = plt.figure(1, figsize=(14,6))
fig1.suptitle('42 Features, Train vs Test MAE', fontsize=16)

ax1 = fig1.add_subplot(1,2,1)
ax1.plot([0, 1, 2, 3, 4, 5], y_train16, '-o')
ax1.plot([0, 1, 2, 3, 4, 5], y_test16, '-o')
ax1.set_xlabel('Model #')
ax1.set_ylabel('Error in MAE')
ax1.legend(('\'16 Train', '\'16 Test'), loc='center right')

#plot 1/k vs train error
ax2 = fig1.add_subplot(1,2,2)
ax2.plot([0, 1, 2, 3, 4, 5], y_train17, '-o')
ax2.plot([0, 1, 2, 3, 4, 5], y_test17, '-o')
ax2.legend(('\'17 Train', '\'17 Test'), loc='center right')
ax2.set_xlabel('Model #')
ax2.set_ylabel('Error in MAE')

plt.show()

# %%
cols1 = ["58 Features", "Model", "Parameters", 
        "\'16 Train", "\'16 Test", "Parameters",
       "\'17 Train", "\'17 Test"]

data2 = [["Baseline", "Linear Regr(OLS)", "None", 0.068438, 0.0652149, "None", 0.070902, 0.0765408],
        ["Model 1", "Lasso", "0.00001", 0.068305, 0.0650119, "0.00002", 0.070681, 0.0761423],
        ["Model 2", "ElasticNet", "0.00001, 0.9", 0.068322, 0.0650136, "0.00002, 0.9", 0.070675, 0.0761873],
        ["Model 3", "Ridge", "1.00", 0.068308, 0.064945, "1.00", 0.070544, 0.0760530],
        ["Model 4", "Ransac + Lasso", "0.8, 10", 0.068011, 0.0648887, "0.8, 10", 0.070005, 0.0757996],
        ["Model 5", "Ransac + Ridge", "0.5, 100", 0.068012, 0.0649349, "0.5, 50", 0.069801, 0.0757544]]

the_table = plt.table(cellText=data2,
                      colLabels=cols1, loc="left")

the_table.set_fontsize(42)
the_table.scale(4, 4)
plt.axis('tight')
plt.axis('off')
plt.show()

# %%
np_data2 = np.array(data2)
x_label = np_data2[:,0]

y_train16 = np_data2[:,3]
y_test16 = np_data2[:,4]

y_train17 = np_data2[:,6]
y_test17 = np_data2[:,7]

fig1 = plt.figure(1, figsize=(14,6))
fig1.suptitle('58 Features, Train vs Test MAE', fontsize=16)

ax1 = fig1.add_subplot(1,2,1)
ax1.plot([0, 1, 2, 3, 4, 5], y_train16, '-o')
ax1.plot([0, 1, 2, 3, 4, 5], y_test16, '-o')
ax1.set_xlabel('Model #')
ax1.set_ylabel('Error in MAE')
ax1.legend(('\'16 Train', '\'16 Test'), loc='center right')

#plot 1/k vs train error
ax2 = fig1.add_subplot(1,2,2)
ax2.plot([0, 1, 2, 3, 4, 5], y_train17, '-o')
ax2.plot([0, 1, 2, 3, 4, 5], y_test17, '-o')
ax2.legend(('\'17 Train', '\'17 Test'), loc='center right')
ax2.set_xlabel('Model #')
ax2.set_ylabel('Error in MAE')

plt.show()

# %%
cols3 = ["Model", "Parameter", "\'16 Train", "\'16 Test", "Parameters", "\'17 Train", "\'17 Test"]
data3 = [["Ridge", "1.00", 0.068285, "n/a", "1.00", 0.070555, "n/a"],
        ["Lasso", "0.000002", 0.068257, "n/a", "0.000002", 0.070553, "n/a"],
        ["XGBoost", "21.5443", 0.0678799, 0.0651854, "21.5443", 0.0703863, 0.0774367],
        ["LightGBM", "n/a", 0.0680900, 0.0648632, "n/a", 0.0705200, 0.0759538]]

the_table = plt.table(cellText=data3,
                      colLabels=cols3, loc="left")

the_table.set_fontsize(20)
the_table.scale(4, 4)
plt.axis('tight')
plt.axis('off')
plt.show()

# %%
col4 = ["42 Features", "Model", "\'16 Train", "\'16 Test", "\'17 Train", "\'17 Test"]
data4 = [["Model 0", "XGBoost (RFE)", 0.0678517, 0.0651735, 0.0702628, 0.0779330],
        ["Model 1", "LightGBM (w/o RFE)", 0.0678600, 0.0648004, 0.0703100, 0.0759538],
        ["Model 2", "LightGBM (RFE)", 0.0678400, 0.0659849, 0.0705300, 0.0759396],
        ["Model 3", "LightGBM (DART)", 0.0676250, 0.0650167, 0.0694580, 0.0763475]]

the_table = plt.table(cellText=data4,
                      colLabels=col4, loc="left")

the_table.set_fontsize(20)
the_table.scale(4, 4)
plt.axis('tight')
plt.axis('off')
plt.show()

# %%
np_data2 = np.array(data4)
x_label = np_data2[:,1]

y_train16 = np_data2[:,2]
y_test16 = np_data2[:,3]

y_train17 = np_data2[:,4]
y_test17 = np_data2[:,5]

fig1 = plt.figure(1, figsize=(14,6))
fig1.suptitle('Train vs Test MAE', fontsize=16)

ax1 = fig1.add_subplot(1,2,1)
ax1.plot([0, 1, 2, 3], y_train16, '-o')
ax1.plot([0, 1, 2, 3], y_test16, '-o')
ax1.set_xticks([0, 1, 2, 3])
ax1.set_xlabel('Model #')
ax1.set_ylabel('Error in MAE')
ax1.legend(('\'16 Train', '\'16 Test'), loc='center right')

#plot 1/k vs train error
ax2 = fig1.add_subplot(1,2,2)
ax2.plot([0, 1, 2, 3], y_train17, '-o')
ax2.plot([0, 1, 2, 3], y_test17, '-o')
ax2.set_xticks([0, 1, 2, 3])
ax2.legend(('\'17 Train', '\'17 Test'), loc='center right')
ax2.set_xlabel('Model #')
ax2.set_ylabel('Error in MAE')

plt.show()

# %%
col5 = ["Model", "Kaggle Rank \'16", "Kaggle Rank \'17"]
data5 = [["LightGBM (w/o RFE)", 2224, 2514],
        ["RANSAC + Lasso/Ridge", 2367, 2104]]

the_table = plt.table(cellText=data5,
                      colLabels=col5, loc="left")

the_table.set_fontsize(20)
the_table.scale(3, 3)
plt.axis('tight')
plt.axis('off')
plt.show()
